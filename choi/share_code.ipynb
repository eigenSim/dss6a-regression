# %%
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk

import matplotlib as mpl
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()

import os
from os.path import dirname
import re
import time
import datetime

# %%
# csv 파일에서 데이터 불러오는 코드

trainfile = 'train.csv'
testfile = 'test.csv'

cols_list = ['pickup_datetime', 'passenger_count', \
             'pickup_latitude', 'pickup_longitude', \
             'dropoff_latitude', 'dropoff_longitude', \
             'trip_duration']

# train.csv
taxi_df = pd.read_csv('../_data/' + trainfile, usecols=cols_list)

# test.csv
test_df = pd.read_csv('../_data/' + testfile, usecols=cols_list[:-1])

# %%
taxi_df.head()
# Out:
#   pickup_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# 0   4/30/16 23:59                1        -73.987793        40.724792
# 1   4/30/16 23:59                1        -73.957596        40.717770
# 2   4/30/16 23:59                2        -74.000954        40.742031
# 3   4/30/16 23:58                1        -73.985733        40.738258
# 4   4/30/16 23:58                1        -74.006615        40.740650
#
#    dropoff_longitude  dropoff_latitude  trip_duration
# 0         -73.975616         40.656445           1454
# 1         -73.951424         40.775230           1409
# 2         -73.947708         40.782200           1081
# 3         -73.993179         40.754890            800
# 4         -73.985619         40.723362           1151

# %%
test_df.head()
# Out:
#   pickup_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# 0   6/30/16 23:59                5        -73.998291        40.722618
# 1   6/30/16 23:59                2        -73.955109        40.689564
# 2   6/30/16 23:59                1        -73.978416        40.791576
# 3   6/30/16 23:59                2        -73.873093        40.774097
# 4   6/30/16 23:58                1        -73.979416        40.755211
#
#    dropoff_longitude  dropoff_latitude
# 0         -73.971779         40.762470
# 1         -73.978203         40.685802
# 2         -73.973160         40.675968
# 3         -73.926704         40.856739
# 4         -74.003548         40.738224
