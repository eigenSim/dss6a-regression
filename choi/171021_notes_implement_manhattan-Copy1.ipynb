# %% [markdown]
# #### train process
# 1. import csv to df
# 1. process df to be modelable
#   1. add variables
#     * dow (cat - 7 vars)
#     * hr (cat - 24 vars)
#         * pair dow with hr?
#     * slow_day (cat - 0, 1)
#     * fast_day (cat - 0, 1)
#     * L2
#         * log L2?
#     * google_dist (needs id?)
#     * weather (needs datetime?)
# 1. model
# 1. use cooksd + fox criterion to identify outliers
# 1. filter outliers and make new df

# %% [markdown]
# encode week-hour (0 - 167)
# implement p_in_manhattan, d_in_manhattan

# %% [markdown]
# ### * contains point

# %%
from shapely.geometry import Polygon
from shapely.geometry import Point
pgon = Polygon([(0, 0), (1, 1), (0, 2), (2, 2), (2, 0)])
print(pgon.area)
pgon.contains(Point(1.001, 1))
# Out:
# 3.0
# True

# %% [markdown]
# ## * need to drop outliers (esp. duration)

# %% [markdown]
# ## * 아래 2칸 실행

# %%
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk

import matplotlib as mpl
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()

# %%
# 경로 변수 (고정)

dataLoc = '../_data/'

trainfile = 'train_03_997.csv'
old_trainfile = 'train.csv'
kaggle_trainfile = 'train_k.csv'

testfile = 'test_clean.csv'
old_testfile = 'test.csv'

train_171016 = '171016_dow_hr_pas_L2_dur_only.csv'
train_osrm = '../_data/train_with_osrm.csv'
train_osrm_weather = '../_data/train_with_osrm_and_weather.csv'
train_osrm_weather_hourly = '../_data/train_with_osrm_and_weather_hourly.csv'
train_dropped_nan_fixed = '../_data/train__dropped__no_disaster_nan_fixed.csv'
train_added_airps = '../_data/train__dropped__lnglat_saved__airports__no_disaster.csv'
train_added_airps_cleaned = '../_data/train__dropped__cleaned__airports__no_disaster.csv'
train_added_airps_disas_cleaned = '../_data/train__dropped__cleaned__eval__airports__disaster.csv'
train_latest = train_added_airps_disas_cleaned

# %% [markdown]
# ## `train_latest` (전처리 전)

# %%
pd.options.display.max_columns = 40

# %%
# train_with_osrm_and_weather.csv
df_train = pd.read_csv(dataLoc + train_latest)
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1  False  False  False
# 1   False      0  430  Saturday  23  0.057791        1  False  False  False
# 2   False      0  430  Saturday  23  0.066698        2  False  False  False
# 3   False      0  430  Saturday  23  0.018223        1  False  False  False
# 4   False      0  430  Saturday  23  0.027198        1  False  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 24 columns]

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1  False  False  False
# 1   False      0  430  Saturday  23  0.057791        1  False  False  False
# 2   False      0  430  Saturday  23  0.066698        2  False  False  False
# 3   False      0  430  Saturday  23  0.018223        1  False  False  False
# 4   False      0  430  Saturday  23  0.027198        1  False  False  False
#
#    d_LGA  total_dist  day_max_temp  day_min_temp  day_rainfall  day_snowfall  \
# 0  False     10010.9            65            46           0.0           0.0
# 1  False     10357.0            65            46           0.0           0.0
# 2  False      9275.8            65            46           0.0           0.0
# 3  False      2726.9            65            46           0.0           0.0
# 4  False      3455.8            65            46           0.0           0.0
#
#    day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  \
# 0            0.0     10.6      0.56       2.2          13.0           0.0
# 1            0.0     10.6      0.56       2.2          13.0           0.0
# 2            0.0     10.6      0.56       2.2          13.0           0.0
# 3            0.0     10.6      0.56       2.2          13.0           0.0
# 4            0.0     10.6      0.56       2.2          13.0           0.0
#
#    hr_precip   dur
# 0        0.0  1454
# 1        0.0  1409
# 2        0.0  1081
# 3        0.0   800
# 4        0.0  1151

# %%
# train_with_osrm_and_weather.csv
df_coord = pd.read_csv(dataLoc + train_added_airps)
df_coord.head()
# Out:
#    is_hol  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  d_LGA  \
# 0   False  430  Saturday  23  0.069424        1  False  False  False  False
# 1   False  430  Saturday  23  0.057791        1  False  False  False  False
# 2   False  430  Saturday  23  0.066698        2  False  False  False  False
# 3   False  430  Saturday  23  0.018223        1  False  False  False  False
# 4   False  430  Saturday  23  0.027198        1  False  False  False  False
#
#        p_lng      p_lat      d_lng      d_lat   dur  total_dist  total_time  \
# 0 -73.987793  40.724792 -73.975616  40.656445  1454     10010.9       861.2
# 1 -73.957596  40.717770 -73.951424  40.775230  1409     10357.0       786.3
# 2 -74.000954  40.742031 -73.947708  40.782200  1081      9275.8       703.9
# 3 -73.985733  40.738258 -73.993179  40.754890   800      2726.9       298.0
# 4 -74.006615  40.740650 -73.985619  40.723362  1151      3455.8       458.2
#
#    day_max_temp  day_min_temp  day_rainfall  day_snowfall  day_snowdepth  \
# 0            65            46           0.0           0.0            0.0
# 1            65            46           0.0           0.0            0.0
# 2            65            46           0.0           0.0            0.0
# 3            65            46           0.0           0.0            0.0
# 4            65            46           0.0           0.0            0.0
#
#    hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip
# 0     10.6      0.56       2.2          13.0           0.0        0.0
# 1     10.6      0.56       2.2          13.0           0.0        0.0
# 2     10.6      0.56       2.2          13.0           0.0        0.0
# 3     10.6      0.56       2.2          13.0           0.0        0.0
# 4     10.6      0.56       2.2          13.0           0.0        0.0

# %%
for col in ['p_lng', 'p_lat', 'd_lng', 'd_lat']:
    df_train[col] = df_coord[col]

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1  False  False  False
# 1   False      0  430  Saturday  23  0.057791        1  False  False  False
# 2   False      0  430  Saturday  23  0.066698        2  False  False  False
# 3   False      0  430  Saturday  23  0.018223        1  False  False  False
# 4   False      0  430  Saturday  23  0.027198        1  False  False  False
#
#    d_LGA  total_dist  day_max_temp  day_min_temp  day_rainfall  day_snowfall  \
# 0  False     10010.9            65            46           0.0           0.0
# 1  False     10357.0            65            46           0.0           0.0
# 2  False      9275.8            65            46           0.0           0.0
# 3  False      2726.9            65            46           0.0           0.0
# 4  False      3455.8            65            46           0.0           0.0
#
#    day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  \
# 0            0.0     10.6      0.56       2.2          13.0           0.0
# 1            0.0     10.6      0.56       2.2          13.0           0.0
# 2            0.0     10.6      0.56       2.2          13.0           0.0
# 3            0.0     10.6      0.56       2.2          13.0           0.0
# 4            0.0     10.6      0.56       2.2          13.0           0.0
#
#    hr_precip   dur      p_lng      p_lat      d_lng      d_lat
# 0        0.0  1454 -73.987793  40.724792 -73.975616  40.656445
# 1        0.0  1409 -73.957596  40.717770 -73.951424  40.775230
# 2        0.0  1081 -74.000954  40.742031 -73.947708  40.782200
# 3        0.0   800 -73.985733  40.738258 -73.993179  40.754890
# 4        0.0  1151 -74.006615  40.740650 -73.985619  40.723362

# %%
df_train.to_csv('../_data/train__dropped__lnglat_saved__airports__disaster.csv', index=False)

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1  False  False  False
# 1   False      0  430  Saturday  23  0.057791        1  False  False  False
# 2   False      0  430  Saturday  23  0.066698        2  False  False  False
# 3   False      0  430  Saturday  23  0.018223        1  False  False  False
# 4   False      0  430  Saturday  23  0.027198        1  False  False  False
#
#    d_LGA  total_dist  day_max_temp  day_min_temp  day_rainfall  day_snowfall  \
# 0  False     10010.9            65            46           0.0           0.0
# 1  False     10357.0            65            46           0.0           0.0
# 2  False      9275.8            65            46           0.0           0.0
# 3  False      2726.9            65            46           0.0           0.0
# 4  False      3455.8            65            46           0.0           0.0
#
#    day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  \
# 0            0.0     10.6      0.56       2.2          13.0           0.0
# 1            0.0     10.6      0.56       2.2          13.0           0.0
# 2            0.0     10.6      0.56       2.2          13.0           0.0
# 3            0.0     10.6      0.56       2.2          13.0           0.0
# 4            0.0     10.6      0.56       2.2          13.0           0.0
#
#    hr_precip   dur      p_lng      p_lat      d_lng      d_lat
# 0        0.0  1454 -73.987793  40.724792 -73.975616  40.656445
# 1        0.0  1409 -73.957596  40.717770 -73.951424  40.775230
# 2        0.0  1081 -74.000954  40.742031 -73.947708  40.782200
# 3        0.0   800 -73.985733  40.738258 -73.993179  40.754890
# 4        0.0  1151 -74.006615  40.740650 -73.985619  40.723362

# %%
from shapely.geometry import Polygon
from shapely.geometry import Point
man_area = Polygon([(-73.971033, 40.806079), (-73.927839, 40.788275), (-73.964102, 40.749439), 
                (-73.974997, 40.709739), (-74.02881, 40.694901), (-74.013784, 40.756599)])

print(man_area.area)
man_area.contains(Point(-74.002548, 40.757777))
# Out:
# 0.005117526720999735
# True

# %%
def in_manhattan(lng, lat):
    man_area = Polygon([(-73.971033, 40.806079), (-73.927839, 40.788275), (-73.964102, 40.749439), 
                (-73.974997, 40.709739), (-74.02881, 40.694901), (-74.013784, 40.756599)])
    return man_area.contains(Point(lng, lat))

in_manhattan(-74.002548, 40.757777)
# Out:
# True

# %%
p_manh = pd.Series(np.vectorize(in_manhattan)(df_train['p_lng'], df_train['p_lat']), name='p_MANH')

# %%
p_manh.sum()
# Out:
# 620438

# %%
p_manh.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: p_MANH, dtype: bool

# %%
d_manh = pd.Series(np.vectorize(in_manhattan)(df_train['d_lng'], df_train['d_lat']), name='d_MANH')

# %%
d_manh.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: d_MANH, dtype: bool

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_JFK  p_LGA  d_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1  False  False  False
# 1   False      0  430  Saturday  23  0.057791        1  False  False  False
# 2   False      0  430  Saturday  23  0.066698        2  False  False  False
# 3   False      0  430  Saturday  23  0.018223        1  False  False  False
# 4   False      0  430  Saturday  23  0.027198        1  False  False  False
#
#    d_LGA  total_dist  day_max_temp  day_min_temp  day_rainfall  day_snowfall  \
# 0  False     10010.9            65            46           0.0           0.0
# 1  False     10357.0            65            46           0.0           0.0
# 2  False      9275.8            65            46           0.0           0.0
# 3  False      2726.9            65            46           0.0           0.0
# 4  False      3455.8            65            46           0.0           0.0
#
#    day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  \
# 0            0.0     10.6      0.56       2.2          13.0           0.0
# 1            0.0     10.6      0.56       2.2          13.0           0.0
# 2            0.0     10.6      0.56       2.2          13.0           0.0
# 3            0.0     10.6      0.56       2.2          13.0           0.0
# 4            0.0     10.6      0.56       2.2          13.0           0.0
#
#    hr_precip   dur      p_lng      p_lat      d_lng      d_lat
# 0        0.0  1454 -73.987793  40.724792 -73.975616  40.656445
# 1        0.0  1409 -73.957596  40.717770 -73.951424  40.775230
# 2        0.0  1081 -74.000954  40.742031 -73.947708  40.782200
# 3        0.0   800 -73.985733  40.738258 -73.993179  40.754890
# 4        0.0  1151 -74.006615  40.740650 -73.985619  40.723362

# %%
df_train.insert(7, 'p_MANH', p_manh)
df_train.insert(8, 'd_MANH', d_manh)

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr        L2  pas_cnt  p_MANH  d_MANH  p_JFK  \
# 0   False      0  430  Saturday  23  0.069424        1    True   False  False
# 1   False      0  430  Saturday  23  0.057791        1   False    True  False
# 2   False      0  430  Saturday  23  0.066698        2    True    True  False
# 3   False      0  430  Saturday  23  0.018223        1    True    True  False
# 4   False      0  430  Saturday  23  0.027198        1    True    True  False
#
#    p_LGA  d_JFK  d_LGA  total_dist  day_max_temp  day_min_temp  day_rainfall  \
# 0  False  False  False     10010.9            65            46           0.0
# 1  False  False  False     10357.0            65            46           0.0
# 2  False  False  False      9275.8            65            46           0.0
# 3  False  False  False      2726.9            65            46           0.0
# 4  False  False  False      3455.8            65            46           0.0
#
#    day_snowfall  day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  \
# 0           0.0            0.0     10.6      0.56       2.2          13.0
# 1           0.0            0.0     10.6      0.56       2.2          13.0
# 2           0.0            0.0     10.6      0.56       2.2          13.0
# 3           0.0            0.0     10.6      0.56       2.2          13.0
# 4           0.0            0.0     10.6      0.56       2.2          13.0
#
#    hr_gustspeed  hr_precip   dur      p_lng      p_lat      d_lng      d_lat
# 0           0.0        0.0  1454 -73.987793  40.724792 -73.975616  40.656445
# 1           0.0        0.0  1409 -73.957596  40.717770 -73.951424  40.775230
# 2           0.0        0.0  1081 -74.000954  40.742031 -73.947708  40.782200
# 3           0.0        0.0   800 -73.985733  40.738258 -73.993179  40.754890
# 4           0.0        0.0  1151 -74.006615  40.740650 -73.985619  40.723362

# %%
(df_train['p_MANH'] & df_train['d_MANH']).sum()
# Out:
# 550676

# %%
df_train.to_csv('../_data/train__dropped__air_bliz_weekhr_manh.csv', index=False)

# %%
model0000 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol) + C(dow):C(hr) + C(p_JFK) + C(p_LGA)\
                            + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res0000 = model0000.fit()
res0000.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     7467.
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:03:47   Log-Likelihood:            -4.9349e+06
# No. Observations:              683021   AIC:                         9.870e+06
# Df Residuals:                  682839   BIC:                         9.872e+06
# Df Model:                         181
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# C(is_hol)[False]                680.5905      5.205    130.760      0.000     670.389     690.792
# C(is_hol)[True]                 595.6562      5.842    101.956      0.000     584.205     607.107
# C(p_JFK)[T.True]               -702.1837      4.374   -160.539      0.000    -710.756    -693.611
# C(p_LGA)[T.True]               -173.4399      2.932    -59.148      0.000    -179.187    -167.693
# C(d_JFK)[T.True]               -656.4282      6.383   -102.838      0.000    -668.939    -643.918
# C(d_LGA)[T.True]               -233.5808      4.184    -55.824      0.000    -241.782    -225.380
# C(hr)[T.1]                      -23.5761      8.206     -2.873      0.004     -39.659      -7.493
# C(hr)[T.2]                      -54.1910      9.179     -5.904      0.000     -72.181     -36.201
# C(hr)[T.3]                      -75.0593     10.166     -7.384      0.000     -94.984     -55.135
# C(hr)[T.4]                     -112.4712     11.365     -9.896      0.000    -134.746     -90.196
# C(hr)[T.5]                     -182.4893     11.215    -16.271      0.000    -204.471    -160.507
# C(hr)[T.6]                      -97.5945      8.332    -11.713      0.000    -113.926     -81.263
# C(hr)[T.7]                       78.3929      7.109     11.027      0.000      64.459      92.326
# C(hr)[T.8]                      220.1442      6.896     31.924      0.000     206.629     233.660
# C(hr)[T.9]                      257.6776      6.976     36.935      0.000     244.004     271.351
# C(hr)[T.10]                     259.0579      7.157     36.195      0.000     245.030     273.086
# C(hr)[T.11]                     261.9064      7.114     36.815      0.000     247.963     275.850
# C(hr)[T.12]                     241.9013      7.017     34.473      0.000     228.148     255.655
# C(hr)[T.13]                     202.1687      7.017     28.811      0.000     188.416     215.922
# C(hr)[T.14]                     248.5425      6.904     36.000      0.000     235.011     262.074
# C(hr)[T.15]                     295.5609      7.012     42.150      0.000     281.817     309.304
# C(hr)[T.16]                     270.7276      7.243     37.377      0.000     256.531     284.924
# C(hr)[T.17]                     244.8075      6.891     35.528      0.000     231.302     258.313
# C(hr)[T.18]                     209.7637      6.594     31.811      0.000     196.840     222.688
# C(hr)[T.19]                     172.0703      6.538     26.319      0.000     159.256     184.884
# C(hr)[T.20]                     131.1205      6.654     19.705      0.000     118.078     144.162
# C(hr)[T.21]                     110.1510      6.688     16.469      0.000      97.042     123.260
# C(hr)[T.22]                     132.7229      6.635     20.005      0.000     119.719     145.726
# C(hr)[T.23]                     126.6309      6.650     19.043      0.000     113.598     139.664
# C(dow)[T.Monday]:C(hr)[0]      -139.1663      9.212    -15.107      0.000    -157.222    -121.110
# C(dow)[T.Saturday]:C(hr)[0]      70.6236      6.795     10.393      0.000      57.306      83.942
# C(dow)[T.Sunday]:C(hr)[0]        73.1405      6.830     10.709      0.000      59.754      86.527
# C(dow)[T.Thursday]:C(hr)[0]     -68.8420      8.258     -8.336      0.000     -85.027     -52.657
# C(dow)[T.Tuesday]:C(hr)[0]     -119.4877      9.230    -12.945      0.000    -137.579    -101.397
# C(dow)[T.Wednesday]:C(hr)[0]    -85.6920      8.706     -9.843      0.000    -102.756     -68.628
# C(dow)[T.Monday]:C(hr)[1]      -118.6428     11.882     -9.985      0.000    -141.931     -95.354
# C(dow)[T.Saturday]:C(hr)[1]      36.3495      7.962      4.565      0.000      20.744      51.955
# C(dow)[T.Sunday]:C(hr)[1]        61.4485      7.924      7.755      0.000      45.918      76.979
# C(dow)[T.Thursday]:C(hr)[1]     -88.2049     10.467     -8.427      0.000    -108.719     -67.691
# C(dow)[T.Tuesday]:C(hr)[1]     -132.6684     11.859    -11.187      0.000    -155.912    -109.425
# C(dow)[T.Wednesday]:C(hr)[1]   -102.4835     11.111     -9.223      0.000    -124.261     -80.706
# C(dow)[T.Monday]:C(hr)[2]       -82.1241     14.821     -5.541      0.000    -111.172     -53.076
# C(dow)[T.Saturday]:C(hr)[2]      37.0149      9.221      4.014      0.000      18.941      55.089
# C(dow)[T.Sunday]:C(hr)[2]        29.3520      9.259      3.170      0.002      11.204      47.500
# C(dow)[T.Thursday]:C(hr)[2]     -80.5408     13.246     -6.080      0.000    -106.502     -54.579
# C(dow)[T.Tuesday]:C(hr)[2]      -99.9972     15.057     -6.641      0.000    -129.509     -70.485
# C(dow)[T.Wednesday]:C(hr)[2]    -79.9144     13.565     -5.891      0.000    -106.502     -53.327
# C(dow)[T.Monday]:C(hr)[3]       -46.2559     17.285     -2.676      0.007     -80.134     -12.378
# C(dow)[T.Saturday]:C(hr)[3]      20.3062     10.714      1.895      0.058      -0.694      41.306
# C(dow)[T.Sunday]:C(hr)[3]        26.9971     10.578      2.552      0.011       6.265      47.729
# C(dow)[T.Thursday]:C(hr)[3]    -103.9471     15.576     -6.673      0.000    -134.476     -73.418
# C(dow)[T.Tuesday]:C(hr)[3]     -100.4170     18.557     -5.411      0.000    -136.788     -64.046
# C(dow)[T.Wednesday]:C(hr)[3]    -73.6210     16.415     -4.485      0.000    -105.794     -41.448
# C(dow)[T.Monday]:C(hr)[4]      -115.0315     17.319     -6.642      0.000    -148.976     -81.087
# C(dow)[T.Saturday]:C(hr)[4]      16.1864     12.847      1.260      0.208      -8.994      41.366
# C(dow)[T.Sunday]:C(hr)[4]        23.8378     12.515      1.905      0.057      -0.692      48.368
# C(dow)[T.Thursday]:C(hr)[4]    -103.7965     16.937     -6.128      0.000    -136.992     -70.601
# C(dow)[T.Tuesday]:C(hr)[4]     -108.6300     18.227     -5.960      0.000    -144.354     -72.906
# C(dow)[T.Wednesday]:C(hr)[4]    -91.3983     17.584     -5.198      0.000    -125.862     -56.934
# C(dow)[T.Monday]:C(hr)[5]       -61.2515     14.838     -4.128      0.000     -90.333     -32.170
# C(dow)[T.Saturday]:C(hr)[5]     -23.7225     15.034     -1.578      0.115     -53.188       5.743
# C(dow)[T.Sunday]:C(hr)[5]        -4.6095     15.050     -0.306      0.759     -34.108      24.889
# C(dow)[T.Thursday]:C(hr)[5]     -23.0494     14.555     -1.584      0.113     -51.577       5.478
# C(dow)[T.Tuesday]:C(hr)[5]      -24.4871     14.718     -1.664      0.096     -53.334       4.360
# C(dow)[T.Wednesday]:C(hr)[5]    -15.1487     14.709     -1.030      0.303     -43.978      13.680
# C(dow)[T.Monday]:C(hr)[6]        -3.7065      9.389     -0.395      0.693     -22.108      14.695
# C(dow)[T.Saturday]:C(hr)[6]    -115.4931     11.777     -9.807      0.000    -138.575     -92.411
# C(dow)[T.Sunday]:C(hr)[6]      -155.1027     12.601    -12.309      0.000    -179.800    -130.406
# C(dow)[T.Thursday]:C(hr)[6]      10.9855      9.140      1.202      0.229      -6.928      28.899
# C(dow)[T.Tuesday]:C(hr)[6]       12.4875      9.223      1.354      0.176      -5.589      30.564
# C(dow)[T.Wednesday]:C(hr)[6]      5.3420      9.220      0.579      0.562     -12.729      23.413
# C(dow)[T.Monday]:C(hr)[7]       -10.1262      7.150     -1.416      0.157     -24.141       3.888
# C(dow)[T.Saturday]:C(hr)[7]    -212.2612      9.417    -22.541      0.000    -230.718    -193.805
# C(dow)[T.Sunday]:C(hr)[7]      -255.6381     10.577    -24.168      0.000    -276.369    -234.907
# C(dow)[T.Thursday]:C(hr)[7]      19.5618      6.819      2.869      0.004       6.197      32.927
# C(dow)[T.Tuesday]:C(hr)[7]       12.5818      6.896      1.825      0.068      -0.934      26.098
# C(dow)[T.Wednesday]:C(hr)[7]     15.8440      6.820      2.323      0.020       2.478      29.210
# C(dow)[T.Monday]:C(hr)[8]       -11.1157      6.585     -1.688      0.091     -24.023       1.792
# C(dow)[T.Saturday]:C(hr)[8]    -287.4326      7.924    -36.272      0.000    -302.964    -271.901
# C(dow)[T.Sunday]:C(hr)[8]      -355.1481      8.801    -40.355      0.000    -372.397    -337.899
# C(dow)[T.Thursday]:C(hr)[8]      36.9233      6.353      5.812      0.000      24.471      49.375
# C(dow)[T.Tuesday]:C(hr)[8]       28.1632      6.414      4.391      0.000      15.592      40.734
# C(dow)[T.Wednesday]:C(hr)[8]     14.3396      6.335      2.264      0.024       1.924      26.756
# C(dow)[T.Monday]:C(hr)[9]       -18.6074      6.691     -2.781      0.005     -31.722      -5.492
# C(dow)[T.Saturday]:C(hr)[9]    -274.2474      7.111    -38.565      0.000    -288.185    -260.309
# C(dow)[T.Sunday]:C(hr)[9]      -355.2434      7.771    -45.712      0.000    -370.475    -340.012
# C(dow)[T.Thursday]:C(hr)[9]      32.3813      6.592      4.912      0.000      19.461      45.302
# C(dow)[T.Tuesday]:C(hr)[9]       45.5890      6.594      6.914      0.000      32.665      58.513
# C(dow)[T.Wednesday]:C(hr)[9]     23.7469      6.605      3.595      0.000      10.801      36.693
# C(dow)[T.Monday]:C(hr)[10]      -31.5160      7.216     -4.368      0.000     -45.658     -17.374
# C(dow)[T.Saturday]:C(hr)[10]   -232.9772      6.944    -33.551      0.000    -246.587    -219.367
# C(dow)[T.Sunday]:C(hr)[10]     -302.2014      7.237    -41.756      0.000    -316.386    -288.017
# C(dow)[T.Thursday]:C(hr)[10]     44.7759      6.945      6.447      0.000      31.163      58.389
# C(dow)[T.Tuesday]:C(hr)[10]      54.2645      7.048      7.700      0.000      40.451      68.078
# C(dow)[T.Wednesday]:C(hr)[10]    41.5126      6.983      5.945      0.000      27.827      55.199
# C(dow)[T.Monday]:C(hr)[11]      -36.6989      7.134     -5.144      0.000     -50.682     -22.716
# C(dow)[T.Saturday]:C(hr)[11]   -188.0574      6.791    -27.692      0.000    -201.367    -174.747
# C(dow)[T.Sunday]:C(hr)[11]     -254.7451      6.904    -36.898      0.000    -268.277    -241.213
# C(dow)[T.Thursday]:C(hr)[11]     54.4436      6.899      7.892      0.000      40.922      67.965
# C(dow)[T.Tuesday]:C(hr)[11]      53.4472      6.981      7.656      0.000      39.765      67.129
# C(dow)[T.Wednesday]:C(hr)[11]    47.9099      6.979      6.865      0.000      34.232      61.588
# C(dow)[T.Monday]:C(hr)[12]      -38.6599      6.961     -5.554      0.000     -52.304     -25.016
# C(dow)[T.Saturday]:C(hr)[12]   -130.1995      6.499    -20.032      0.000    -142.938    -117.461
# C(dow)[T.Sunday]:C(hr)[12]     -197.2517      6.707    -29.410      0.000    -210.397    -184.106
# C(dow)[T.Thursday]:C(hr)[12]     69.3534      6.729     10.307      0.000      56.165      82.542
# C(dow)[T.Tuesday]:C(hr)[12]      51.0753      6.850      7.457      0.000      37.650      64.500
# C(dow)[T.Wednesday]:C(hr)[12]    65.9462      6.771      9.739      0.000      52.675      79.218
# C(dow)[T.Monday]:C(hr)[13]      -39.3274      6.992     -5.624      0.000     -53.032     -25.623
# C(dow)[T.Saturday]:C(hr)[13]    -49.6676      6.494     -7.648      0.000     -62.396     -36.939
# C(dow)[T.Sunday]:C(hr)[13]     -114.6983      6.675    -17.183      0.000    -127.781    -101.615
# C(dow)[T.Thursday]:C(hr)[13]     77.5589      6.765     11.465      0.000      64.300      90.818
# C(dow)[T.Tuesday]:C(hr)[13]      70.4295      6.841     10.295      0.000      57.022      83.837
# C(dow)[T.Wednesday]:C(hr)[13]    95.7653      6.789     14.107      0.000      82.460     109.071
# C(dow)[T.Monday]:C(hr)[14]      -64.2782      6.686     -9.614      0.000     -77.383     -51.174
# C(dow)[T.Saturday]:C(hr)[14]   -107.3621      6.429    -16.699      0.000    -119.963     -94.761
# C(dow)[T.Sunday]:C(hr)[14]     -123.2541      6.578    -18.738      0.000    -136.147    -110.362
# C(dow)[T.Thursday]:C(hr)[14]     67.5948      6.509     10.385      0.000      54.838      80.352
# C(dow)[T.Tuesday]:C(hr)[14]      20.3637      6.597      3.087      0.002       7.434      33.293
# C(dow)[T.Wednesday]:C(hr)[14]    42.9203      6.585      6.517      0.000      30.013      55.828
# C(dow)[T.Monday]:C(hr)[15]      -94.5099      6.838    -13.822      0.000    -107.912     -81.108
# C(dow)[T.Saturday]:C(hr)[15]   -135.5077      6.560    -20.656      0.000    -148.366    -122.650
# C(dow)[T.Sunday]:C(hr)[15]     -173.5185      6.744    -25.729      0.000    -186.737    -160.300
# C(dow)[T.Thursday]:C(hr)[15]     19.3627      6.684      2.897      0.004       6.261      32.464
# C(dow)[T.Tuesday]:C(hr)[15]     -27.8946      6.773     -4.118      0.000     -41.170     -14.619
# C(dow)[T.Wednesday]:C(hr)[15]    -5.0314      6.752     -0.745      0.456     -18.265       8.202
# C(dow)[T.Monday]:C(hr)[16]      -92.4852      7.197    -12.851      0.000    -106.591     -78.379
# C(dow)[T.Saturday]:C(hr)[16]   -109.7034      6.891    -15.921      0.000    -123.209     -96.198
# C(dow)[T.Sunday]:C(hr)[16]     -136.9635      6.993    -19.586      0.000    -150.669    -123.258
# C(dow)[T.Thursday]:C(hr)[16]     24.8813      7.235      3.439      0.001      10.700      39.062
# C(dow)[T.Tuesday]:C(hr)[16]     -23.1758      7.224     -3.208      0.001     -37.335      -9.017
# C(dow)[T.Wednesday]:C(hr)[16]    -0.4220      7.176     -0.059      0.953     -14.487      13.643
# C(dow)[T.Monday]:C(hr)[17]      -69.3818      6.507    -10.662      0.000     -82.136     -56.628
# C(dow)[T.Saturday]:C(hr)[17]    -66.1783      6.304    -10.498      0.000     -78.534     -53.822
# C(dow)[T.Sunday]:C(hr)[17]     -122.2783      6.494    -18.830      0.000    -135.006    -109.550
# C(dow)[T.Thursday]:C(hr)[17]     30.9233      6.500      4.758      0.000      18.184      43.662
# C(dow)[T.Tuesday]:C(hr)[17]       4.4655      6.482      0.689      0.491      -8.238      17.169
# C(dow)[T.Wednesday]:C(hr)[17]    35.5821      6.478      5.492      0.000      22.885      48.280
# C(dow)[T.Monday]:C(hr)[18]      -70.0841      5.853    -11.974      0.000     -81.556     -58.613
# C(dow)[T.Saturday]:C(hr)[18]    -18.4363      5.794     -3.182      0.001     -29.793      -7.079
# C(dow)[T.Sunday]:C(hr)[18]     -110.6060      6.161    -17.953      0.000    -122.681     -98.531
# C(dow)[T.Thursday]:C(hr)[18]     40.9475      5.787      7.076      0.000      29.605      52.290
# C(dow)[T.Tuesday]:C(hr)[18]       1.9637      5.828      0.337      0.736      -9.460      13.387
# C(dow)[T.Wednesday]:C(hr)[18]    11.6162      5.819      1.996      0.046       0.210      23.022
# C(dow)[T.Monday]:C(hr)[19]     -125.2869      5.898    -21.241      0.000    -136.848    -113.726
# C(dow)[T.Saturday]:C(hr)[19]     35.1884      5.708      6.164      0.000      24.000      46.377
# C(dow)[T.Sunday]:C(hr)[19]     -122.8417      6.317    -19.446      0.000    -135.223    -110.460
# C(dow)[T.Thursday]:C(hr)[19]     -7.8445      5.702     -1.376      0.169     -19.020       3.331
# C(dow)[T.Tuesday]:C(hr)[19]     -66.5160      5.796    -11.476      0.000     -77.876     -55.156
# C(dow)[T.Wednesday]:C(hr)[19]   -44.2393      5.756     -7.686      0.000     -55.521     -32.958
# C(dow)[T.Monday]:C(hr)[20]     -142.9641      6.188    -23.102      0.000    -155.093    -130.835
# C(dow)[T.Saturday]:C(hr)[20]     28.4689      6.103      4.665      0.000      16.508      40.430
# C(dow)[T.Sunday]:C(hr)[20]     -137.6389      6.628    -20.767      0.000    -150.629    -124.649
# C(dow)[T.Thursday]:C(hr)[20]    -30.8149      5.879     -5.242      0.000     -42.337     -19.293
# C(dow)[T.Tuesday]:C(hr)[20]     -88.0072      5.970    -14.741      0.000     -99.709     -76.306
# C(dow)[T.Wednesday]:C(hr)[20]   -61.3248      5.930    -10.342      0.000     -72.947     -49.703
# C(dow)[T.Monday]:C(hr)[21]     -139.7359      6.310    -22.145      0.000    -152.104    -127.368
# C(dow)[T.Saturday]:C(hr)[21]     15.8518      6.119      2.591      0.010       3.859      27.844
# C(dow)[T.Sunday]:C(hr)[21]     -147.7791      6.771    -21.824      0.000    -161.051    -134.507
# C(dow)[T.Thursday]:C(hr)[21]    -18.7440      5.892     -3.181      0.001     -30.291      -7.197
# C(dow)[T.Tuesday]:C(hr)[21]     -96.8004      6.061    -15.970      0.000    -108.680     -84.921
# C(dow)[T.Wednesday]:C(hr)[21]   -65.5167      5.976    -10.964      0.000     -77.229     -53.805
# C(dow)[T.Monday]:C(hr)[22]     -174.8197      6.584    -26.553      0.000    -187.724    -161.916
# C(dow)[T.Saturday]:C(hr)[22]     10.2164      5.944      1.719      0.086      -1.433      21.866
# C(dow)[T.Sunday]:C(hr)[22]     -198.4199      6.962    -28.500      0.000    -212.066    -184.774
# C(dow)[T.Thursday]:C(hr)[22]    -49.8130      5.915     -8.421      0.000     -61.407     -38.219
# C(dow)[T.Tuesday]:C(hr)[22]    -125.2616      6.192    -20.228      0.000    -137.399    -113.124
# C(dow)[T.Wednesday]:C(hr)[22]   -95.2735      6.082    -15.664      0.000    -107.195     -83.352
# C(dow)[T.Monday]:C(hr)[23]     -209.3888      7.354    -28.472      0.000    -223.803    -194.975
# C(dow)[T.Saturday]:C(hr)[23]     -0.2761      5.846     -0.047      0.962     -11.735      11.182
# C(dow)[T.Sunday]:C(hr)[23]     -236.4856      7.605    -31.096      0.000    -251.391    -221.580
# C(dow)[T.Thursday]:C(hr)[23]    -84.8416      6.156    -13.781      0.000     -96.908     -72.776
# C(dow)[T.Tuesday]:C(hr)[23]    -178.5295      6.791    -26.290      0.000    -191.839    -165.220
# C(dow)[T.Wednesday]:C(hr)[23]  -133.3245      6.574    -20.280      0.000    -146.210    -120.439
# scale(blizz)                      5.3568      1.254      4.271      0.000       2.899       7.815
# scale(total_dist)               522.9338      0.571    916.388      0.000     521.815     524.052
# scale(day_max_temp)              11.3324      1.172      9.667      0.000       9.035      13.630
# scale(day_rainfall)              -1.3094      0.518     -2.529      0.011      -2.324      -0.295
# scale(day_snowfall)               2.7522      0.632      4.356      0.000       1.514       3.991
# scale(day_snowdepth)             20.0518      1.148     17.465      0.000      17.801      22.302
# scale(hr_temp)                    5.4432      1.195      4.555      0.000       3.101       7.785
# scale(hr_humid)                  -1.0619      0.494     -2.149      0.032      -2.030      -0.094
# scale(hr_windspeed)               6.1903      0.430     14.398      0.000       5.348       7.033
# ==============================================================================
# Omnibus:                   236048.585   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2135671.393
# Skew:                           1.407   Prob(JB):                         0.00
# Kurtosis:                      11.193   Cond. No.                         114.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model00000 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol) + scale(weekhour) + C(p_JFK) + C(p_LGA)\
                            + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res00000 = model00000.fit()
res00000.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                 7.364e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        14:57:03   Log-Likelihood:            -4.9791e+06
# No. Observations:              683021   AIC:                         9.958e+06
# Df Residuals:                  683005   BIC:                         9.959e+06
# Df Model:                          15
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# C(is_hol)[False]       806.2943      0.454   1774.414      0.000     805.404     807.185
# C(is_hol)[True]        679.2956      2.975    228.323      0.000     673.464     685.127
# C(p_JFK)[T.True]      -627.7898      4.645   -135.146      0.000    -636.894    -618.685
# C(p_LGA)[T.True]      -111.6602      3.110    -35.902      0.000    -117.756    -105.564
# C(d_JFK)[T.True]      -558.5352      6.779    -82.397      0.000    -571.821    -545.249
# C(d_LGA)[T.True]      -182.1063      4.428    -41.130      0.000    -190.784    -173.428
# scale(blizz)            -2.1739      1.317     -1.651      0.099      -4.755       0.408
# scale(weekhour)        -26.2896      0.444    -59.259      0.000     -27.159     -25.420
# scale(total_dist)      500.1566      0.601    832.687      0.000     498.979     501.334
# scale(day_max_temp)    -52.3688      1.074    -48.753      0.000     -54.474     -50.263
# scale(day_rainfall)     -1.2112      0.532     -2.276      0.023      -2.254      -0.168
# scale(day_snowfall)      2.7369      0.655      4.180      0.000       1.454       4.020
# scale(day_snowdepth)    20.8291      1.210     17.211      0.000      18.457      23.201
# scale(hr_temp)          75.8884      1.065     71.281      0.000      73.802      77.975
# scale(hr_humid)        -13.1060      0.496    -26.400      0.000     -14.079     -12.133
# scale(hr_windspeed)     11.1894      0.442     25.329      0.000      10.324      12.055
# ==============================================================================
# Omnibus:                   231051.313   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1653121.132
# Skew:                           1.445   Prob(JB):                         0.00
# Kurtosis:                      10.052   Cond. No.                         24.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model1 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol)\
                            + scale(weekhour) + scale(I(weekhour**2)) \
                            + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res1 = model1.fit()
res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                 7.020e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        14:59:43   Log-Likelihood:            -4.9756e+06
# No. Observations:              683021   AIC:                         9.951e+06
# Df Residuals:                  683004   BIC:                         9.951e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# C(is_hol)[False]          805.5286      0.452   1781.544      0.000     804.642     806.415
# C(is_hol)[True]           706.3780      2.977    237.258      0.000     700.543     712.213
# C(p_JFK)[T.True]         -622.5136      4.622   -134.692      0.000    -631.572    -613.455
# C(p_LGA)[T.True]         -107.8115      3.094    -34.840      0.000    -113.877    -101.746
# C(d_JFK)[T.True]         -555.3204      6.744    -82.345      0.000    -568.538    -542.103
# C(d_LGA)[T.True]         -184.4412      4.405    -41.872      0.000    -193.074    -175.808
# scale(blizz)                1.0232      1.311      0.781      0.435      -1.546       3.592
# scale(weekhour)           121.9654      1.815     67.191      0.000     118.408     125.523
# scale(I(weekhour ** 2))  -151.5933      1.800    -84.201      0.000    -155.122    -148.065
# scale(total_dist)         500.3946      0.598    837.386      0.000     499.223     501.566
# scale(day_max_temp)       -45.8562      1.071    -42.799      0.000     -47.956     -43.756
# scale(day_rainfall)         4.1248      0.533      7.738      0.000       3.080       5.170
# scale(day_snowfall)        -1.2134      0.653     -1.858      0.063      -2.493       0.067
# scale(day_snowdepth)       21.7291      1.204     18.046      0.000      19.369      24.089
# scale(hr_temp)             68.0198      1.063     63.972      0.000      65.936      70.104
# scale(hr_humid)           -15.9612      0.495    -32.242      0.000     -16.932     -14.991
# scale(hr_windspeed)        12.1105      0.440     27.547      0.000      11.249      12.972
# ==============================================================================
# Omnibus:                   230238.699   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1669770.558
# Skew:                           1.435   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         24.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model11 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol)\
                            + scale(weekhour) + I(scale(weekhour)**2) \
                            + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res11 = model11.fit()
res11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                 7.020e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        15:04:40   Log-Likelihood:            -4.9756e+06
# No. Observations:              683021   AIC:                         9.951e+06
# Df Residuals:                  683004   BIC:                         9.951e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# C(is_hol)[False]          845.5963      0.650   1301.334      0.000     844.323     846.870
# C(is_hol)[True]           746.4458      3.065    243.508      0.000     740.438     752.454
# C(p_JFK)[T.True]         -622.5136      4.622   -134.692      0.000    -631.572    -613.455
# C(p_LGA)[T.True]         -107.8115      3.094    -34.840      0.000    -113.877    -101.746
# C(d_JFK)[T.True]         -555.3204      6.744    -82.345      0.000    -568.538    -542.103
# C(d_LGA)[T.True]         -184.4412      4.405    -41.872      0.000    -193.074    -175.808
# scale(blizz)                1.0232      1.311      0.781      0.435      -1.546       3.592
# scale(weekhour)           -28.6405      0.442    -64.763      0.000     -29.507     -27.774
# I(scale(weekhour) ** 2)   -40.0678      0.476    -84.201      0.000     -41.000     -39.135
# scale(total_dist)         500.3946      0.598    837.386      0.000     499.223     501.566
# scale(day_max_temp)       -45.8562      1.071    -42.799      0.000     -47.956     -43.756
# scale(day_rainfall)         4.1248      0.533      7.738      0.000       3.080       5.170
# scale(day_snowfall)        -1.2134      0.653     -1.858      0.063      -2.493       0.067
# scale(day_snowdepth)       21.7291      1.204     18.046      0.000      19.369      24.089
# scale(hr_temp)             68.0198      1.063     63.972      0.000      65.936      70.104
# scale(hr_humid)           -15.9612      0.495    -32.242      0.000     -16.932     -14.991
# scale(hr_windspeed)        12.1105      0.440     27.547      0.000      11.249      12.972
# ==============================================================================
# Omnibus:                   230238.699   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1669770.558
# Skew:                           1.435   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         25.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model11 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol)\
                            + scale(weekhour) + scale(I(weekhour**2)) \
                            + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res11 = model11.fit()
res11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                 7.020e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        15:09:47   Log-Likelihood:            -4.9756e+06
# No. Observations:              683021   AIC:                         9.951e+06
# Df Residuals:                  683004   BIC:                         9.951e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# C(is_hol)[False]          805.5286      0.452   1781.544      0.000     804.642     806.415
# C(is_hol)[True]           706.3780      2.977    237.258      0.000     700.543     712.213
# C(p_JFK)[T.True]         -622.5136      4.622   -134.692      0.000    -631.572    -613.455
# C(p_LGA)[T.True]         -107.8115      3.094    -34.840      0.000    -113.877    -101.746
# C(d_JFK)[T.True]         -555.3204      6.744    -82.345      0.000    -568.538    -542.103
# C(d_LGA)[T.True]         -184.4412      4.405    -41.872      0.000    -193.074    -175.808
# scale(blizz)                1.0232      1.311      0.781      0.435      -1.546       3.592
# scale(weekhour)           121.9654      1.815     67.191      0.000     118.408     125.523
# scale(I(weekhour ** 2))  -151.5933      1.800    -84.201      0.000    -155.122    -148.065
# scale(total_dist)         500.3946      0.598    837.386      0.000     499.223     501.566
# scale(day_max_temp)       -45.8562      1.071    -42.799      0.000     -47.956     -43.756
# scale(day_rainfall)         4.1248      0.533      7.738      0.000       3.080       5.170
# scale(day_snowfall)        -1.2134      0.653     -1.858      0.063      -2.493       0.067
# scale(day_snowdepth)       21.7291      1.204     18.046      0.000      19.369      24.089
# scale(hr_temp)             68.0198      1.063     63.972      0.000      65.936      70.104
# scale(hr_humid)           -15.9612      0.495    -32.242      0.000     -16.932     -14.991
# scale(hr_windspeed)        12.1105      0.440     27.547      0.000      11.249      12.972
# ==============================================================================
# Omnibus:                   230238.699   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1669770.558
# Skew:                           1.435   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         24.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
a = 'b'
a += 'c'
a
# Out:
# 'bc'

# %%
def poly_string(var_, deg):
    poly_sum = 'scale(x)'
    for pwr in range(2, deg+1):
        poly_sum += ' + scale(I({}**{}))'.format(var_, pwr)
    return poly_sum

poly_string('weekhour', 4)
# Out:
# 'scale(x) + scale(I(weekhour**2)) + scale(I(weekhour**3)) + scale(I(weekhour**4))'

# %%
quant_vars = [['blizz', 1],
              ['weekhour', 5],
              ['total_dist', 1],
              ['day_max_temp', 1],
              ['day_rainfall', 1],
              ['day_snowfall', 1],
              ['day_snowdepth', 1],
              ['hr_temp', 1],
              ['hr_humid', 1],
              ['hr_windspeed', 1]]


cat_vars = [['is_hol', 1],
            ['p_JFK', 1],
            ['p_LGA', 1],
            ['d_JFK', 1],
            ['d_LGA', 1]]

# %%
def set_degree(var_, deg, pairs):
    pairs = dict(pairs)
    pairs[var_] = deg
    return list(pairs.items())

set_degree('weekhour', 3, quant_vars)
# Out:
# [('blizz', 1),
#  ('weekhour', 3),
#  ('total_dist', 1),
#  ('day_max_temp', 1),
#  ('day_rainfall', 1),
#  ('day_snowfall', 1),
#  ('day_snowdepth', 1),
#  ('hr_temp', 1),
#  ('hr_humid', 1),
#  ('hr_windspeed', 1)]

# %%
def poly_string(var_, deg, scale_=True):
    
    poly_sum = 'scale({})'.format(var_) if scale_ else var_
    for pwr in range(2, deg+1):
        nth_deg = ' + scale(I({}**{}))'.format(var_, pwr) if scale_\
                  else ' + I({}**{})'.format(var_, pwr)
        poly_sum += nth_deg
    return poly_sum

print(poly_string('aaa', 12, True))
print(poly_string('aaa', 12, False))
# Out:
# scale(aaa) + scale(I(aaa**2)) + scale(I(aaa**3)) + scale(I(aaa**4)) + scale(I(aaa**5)) + scale(I(aaa**6)) + scale(I(aaa**7)) + scale(I(aaa**8)) + scale(I(aaa**9)) + scale(I(aaa**10)) + scale(I(aaa**11)) + scale(I(aaa**12))
# aaa + I(aaa**2) + I(aaa**3) + I(aaa**4) + I(aaa**5) + I(aaa**6) + I(aaa**7) + I(aaa**8) + I(aaa**9) + I(aaa**10) + I(aaa**11) + I(aaa**12)

# %%
#automation of r-style from_formula
def make_formula(df, quant_list, cat_list, y_str, const_=True, scale_=True): 
    scale_st, scale_en = ("scale(", ")") if scale_ else ("", "")    
    constadd = "" if const_ else " - 1"  
    model_str = "{} ~ ".format(y_str)
    
    for i, (col, deg) in enumerate(quant_list):
        if i == 0:
            prefix = ""
        else:
            prefix = " + "
        model_str += prefix + poly_string(col, deg, scale_)
    
    for i, (col, _) in enumerate(cat_list):
        prefix = " + "
        model_str += prefix + "C(" + col + ")"
    model_str += constadd

    return model_str

# %%
make_formula(df_copy, quant_vars, cat_vars, 'dur', const_=True, scale_=True)
# Out:
# 'dur ~ scale(blizz) + scale(weekhour) + scale(I(weekhour**2)) + scale(I(weekhour**3)) + scale(I(weekhour**4)) + scale(I(weekhour**5)) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)'

# %%
def get_results(df, quant_list, cat_list, y_str, const=True, scale_=True, fmla=None):
    if not fmla:
        fmla = make_formula(df, quant_list, cat_list, y_str, const, scale_)
    print(fmla)
    mod = sm.OLS.from_formula(fmla, data=df)
    res = mod.fit()
    return mod, res

ols_vars_orig = [df_copy, quant_vars, cat_vars, 'dur', True, True]
ols_vars = ols_vars_orig

quant_vars = set_degree('blizz', 1, quant_vars)
quant_vars = set_degree('weekhour', 14, quant_vars)
ols_vars = [df_copy, quant_vars, cat_vars, 'dur', True, True]
print(ols_vars[1:])
#mod, res = get_results(*ols_vars)
# Out:
# [[('blizz', 1), ('weekhour', 14), ('total_dist', 1), ('day_max_temp', 1), ('day_rainfall', 1), ('day_snowfall', 1), ('day_snowdepth', 1), ('hr_temp', 1), ('hr_humid', 1), ('hr_windspeed', 1)], [['is_hol', 1], ['p_JFK', 1], ['p_LGA', 1], ['d_JFK', 1], ['d_LGA', 1]], 'dur', True, True]

# %%
quant_vars = set_degree('blizz', 1, quant_vars)
quant_vars = set_degree('weekhour', 1, quant_vars)
ols_vars = [df_copy, quant_vars, cat_vars, 'dur', False, True]

formula = make_formula(*ols_vars)

print(formula)
# Out:
# dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA) - 1

# %%
formula = 'dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK)*C(d_LGA) + C(p_LGA)*C(d_JFK)'
print(formula)
# Out:
# dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK)*C(d_LGA) + C(p_LGA)*C(d_JFK)

# %%
formula = 'dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK) + C(d_LGA) + C(p_LGA)*C(d_JFK) - 1'
print(formula)
# Out:
# dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK) + C(d_LGA) + C(p_LGA)*C(d_JFK) - 1

# %%
print(ols_vars[1:])
mod, res = get_results(*ols_vars, formula)
# Out:
# [[('blizz', 1), ('weekhour', 1), ('total_dist', 1), ('day_max_temp', 1), ('day_rainfall', 1), ('day_snowfall', 1), ('day_snowdepth', 1), ('hr_temp', 1), ('hr_humid', 1), ('hr_windspeed', 1)], [['is_hol', 1], ['p_JFK', 1], ['p_LGA', 1], ['d_JFK', 1], ['d_LGA', 1]], 'dur', False, True]
# dur ~ scale(blizz) + scale(weekhour) + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall) + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) + C(is_hol) + C(p_JFK) + C(d_LGA) + C(p_LGA)*C(d_JFK) - 1

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                 6.904e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:43:44   Log-Likelihood:            -4.9791e+06
# No. Observations:              683021   AIC:                         9.958e+06
# Df Residuals:                  683004   BIC:                         9.959e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(is_hol)[False]                    806.2631      0.455   1773.911      0.000     805.372     807.154
# C(is_hol)[True]                     679.2574      2.975    228.310      0.000     673.426     685.089
# C(p_JFK)[T.True]                   -627.3598      4.647   -134.993      0.000    -636.468    -618.251
# C(d_LGA)[T.True]                   -181.8879      4.428    -41.076      0.000    -190.567    -173.209
# C(p_LGA)[T.True]                   -110.7511      3.124    -35.449      0.000    -116.874    -104.628
# C(d_JFK)[T.True]                   -554.6552      6.895    -80.439      0.000    -568.170    -541.141
# C(p_LGA)[T.True]:C(d_JFK)[T.True]  -110.5649     36.011     -3.070      0.002    -181.144     -39.985
# scale(blizz)                         -2.1838      1.317     -1.658      0.097      -4.765       0.398
# scale(weekhour)                     -26.2864      0.444    -59.252      0.000     -27.156     -25.417
# scale(total_dist)                   500.0534      0.602    831.221      0.000     498.874     501.233
# scale(day_max_temp)                 -52.3749      1.074    -48.759      0.000     -54.480     -50.270
# scale(day_rainfall)                  -1.2107      0.532     -2.276      0.023      -2.254      -0.168
# scale(day_snowfall)                   2.7413      0.655      4.186      0.000       1.458       4.025
# scale(day_snowdepth)                 20.8364      1.210     17.217      0.000      18.464      23.208
# scale(hr_temp)                       75.8954      1.065     71.288      0.000      73.809      77.982
# scale(hr_humid)                     -13.1054      0.496    -26.399      0.000     -14.078     -12.132
# scale(hr_windspeed)                  11.1869      0.442     25.323      0.000      10.321      12.053
# ==============================================================================
# Omnibus:                   230994.138   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1652168.781
# Skew:                           1.445   Prob(JB):                         0.00
# Kurtosis:                      10.050   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                 6.904e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:41:46   Log-Likelihood:            -4.9791e+06
# No. Observations:              683021   AIC:                         9.958e+06
# Df Residuals:                  683004   BIC:                         9.959e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           806.2631      0.455   1773.911      0.000     805.372     807.154
# C(is_hol)[T.True]                  -127.0057      3.008    -42.221      0.000    -132.901    -121.110
# C(p_JFK)[T.True]                   -627.3598      4.647   -134.993      0.000    -636.468    -618.251
# C(d_LGA)[T.True]                   -181.8879      4.428    -41.076      0.000    -190.567    -173.209
# C(p_LGA)[T.True]                   -110.7511      3.124    -35.449      0.000    -116.874    -104.628
# C(d_JFK)[T.True]                   -554.6552      6.895    -80.439      0.000    -568.170    -541.141
# C(p_LGA)[T.True]:C(d_JFK)[T.True]  -110.5649     36.011     -3.070      0.002    -181.144     -39.985
# scale(blizz)                         -2.1838      1.317     -1.658      0.097      -4.765       0.398
# scale(weekhour)                     -26.2864      0.444    -59.252      0.000     -27.156     -25.417
# scale(total_dist)                   500.0534      0.602    831.221      0.000     498.874     501.233
# scale(day_max_temp)                 -52.3749      1.074    -48.759      0.000     -54.480     -50.270
# scale(day_rainfall)                  -1.2107      0.532     -2.276      0.023      -2.254      -0.168
# scale(day_snowfall)                   2.7413      0.655      4.186      0.000       1.458       4.025
# scale(day_snowdepth)                 20.8364      1.210     17.217      0.000      18.464      23.208
# scale(hr_temp)                       75.8954      1.065     71.288      0.000      73.809      77.982
# scale(hr_humid)                     -13.1054      0.496    -26.399      0.000     -14.078     -12.132
# scale(hr_windspeed)                  11.1869      0.442     25.323      0.000      10.321      12.053
# ==============================================================================
# Omnibus:                   230994.138   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1652168.781
# Skew:                           1.445   Prob(JB):                         0.00
# Kurtosis:                      10.050   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                 6.498e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:40:11   Log-Likelihood:            -4.9791e+06
# No. Observations:              683021   AIC:                         9.958e+06
# Df Residuals:                  683003   BIC:                         9.959e+06
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           806.2619      0.455   1773.463      0.000     805.371     807.153
# C(is_hol)[T.True]                  -127.0055      3.008    -42.221      0.000    -132.901    -121.110
# C(p_JFK)[T.True]                   -627.2962      4.680   -134.031      0.000    -636.469    -618.123
# C(d_LGA)[T.True]                   -181.8216      4.466    -40.716      0.000    -190.574    -173.069
# C(p_LGA)[T.True]                   -110.7429      3.125    -35.437      0.000    -116.868    -104.618
# C(d_JFK)[T.True]                   -554.6391      6.897    -80.420      0.000    -568.157    -541.122
# C(p_JFK)[T.True]:C(d_LGA)[T.True]    -4.1291     35.971     -0.115      0.909     -74.632      66.373
# C(p_LGA)[T.True]:C(d_JFK)[T.True]  -110.5760     36.011     -3.071      0.002    -181.156     -39.996
# scale(blizz)                         -2.1838      1.317     -1.658      0.097      -4.765       0.398
# scale(weekhour)                     -26.2862      0.444    -59.251      0.000     -27.156     -25.417
# scale(total_dist)                   500.0497      0.602    830.008      0.000     498.869     501.231
# scale(day_max_temp)                 -52.3747      1.074    -48.759      0.000     -54.480     -50.269
# scale(day_rainfall)                  -1.2108      0.532     -2.276      0.023      -2.254      -0.168
# scale(day_snowfall)                   2.7414      0.655      4.187      0.000       1.458       4.025
# scale(day_snowdepth)                 20.8364      1.210     17.217      0.000      18.464      23.208
# scale(hr_temp)                       75.8951      1.065     71.287      0.000      73.808      77.982
# scale(hr_humid)                     -13.1054      0.496    -26.399      0.000     -14.078     -12.132
# scale(hr_windspeed)                  11.1868      0.442     25.323      0.000      10.321      12.053
# ==============================================================================
# Omnibus:                   230992.631   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1652141.422
# Skew:                           1.445   Prob(JB):                         0.00
# Kurtosis:                      10.050   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#dropping outliers by fox_critiria
def dropping_outliers1(x, y):
    x1 = sm.add_constant(x)
    model = sm.OLS(y, x1)
    result = model.fit()
    influence = result.get_influence()
    cooks_d2, pvals = influence.cooks_distance
    fox_cr = 4 / (len(y) - len(x.columns) -1)
    idx = np.where(cooks_d2 > fox_cr)[0]
    x = x.drop(x.index[idx])

# %%
  
#     fmla = 'dur ~ scale(blizz) + C(is_hol)\
#                 + scale(weekhour) + scale(I(weekhour**2)) \
#                 + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
#                 + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
#                 + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
#                 + scale(hr_windspeed) - 1'

model11 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol)\
                            + scale(weekhour) + scale(I(weekhour**2)) \
                            + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res11 = model11.fit()
res11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                 7.020e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        15:09:47   Log-Likelihood:            -4.9756e+06
# No. Observations:              683021   AIC:                         9.951e+06
# Df Residuals:                  683004   BIC:                         9.951e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# C(is_hol)[False]          805.5286      0.452   1781.544      0.000     804.642     806.415
# C(is_hol)[True]           706.3780      2.977    237.258      0.000     700.543     712.213
# C(p_JFK)[T.True]         -622.5136      4.622   -134.692      0.000    -631.572    -613.455
# C(p_LGA)[T.True]         -107.8115      3.094    -34.840      0.000    -113.877    -101.746
# C(d_JFK)[T.True]         -555.3204      6.744    -82.345      0.000    -568.538    -542.103
# C(d_LGA)[T.True]         -184.4412      4.405    -41.872      0.000    -193.074    -175.808
# scale(blizz)                1.0232      1.311      0.781      0.435      -1.546       3.592
# scale(weekhour)           121.9654      1.815     67.191      0.000     118.408     125.523
# scale(I(weekhour ** 2))  -151.5933      1.800    -84.201      0.000    -155.122    -148.065
# scale(total_dist)         500.3946      0.598    837.386      0.000     499.223     501.566
# scale(day_max_temp)       -45.8562      1.071    -42.799      0.000     -47.956     -43.756
# scale(day_rainfall)         4.1248      0.533      7.738      0.000       3.080       5.170
# scale(day_snowfall)        -1.2134      0.653     -1.858      0.063      -2.493       0.067
# scale(day_snowdepth)       21.7291      1.204     18.046      0.000      19.369      24.089
# scale(hr_temp)             68.0198      1.063     63.972      0.000      65.936      70.104
# scale(hr_humid)           -15.9612      0.495    -32.242      0.000     -16.932     -14.991
# scale(hr_windspeed)        12.1105      0.440     27.547      0.000      11.249      12.972
# ==============================================================================
# Omnibus:                   230238.699   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1669770.558
# Skew:                           1.435   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         24.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# def poly_string(var_):
#     'scale'

# def poly_weekhour(deg):
    
#     fmla = 'dur ~ scale(blizz) + C(is_hol)\
#                 + scale(weekhour) + scale(I(weekhour**2)) \
#                 + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
#                 + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
#                 + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
#                 + scale(hr_windspeed) - 1'

model11 = sm.OLS.from_formula('dur ~ scale(blizz) + C(is_hol)\
                            + scale(I(weekhour**1)) + scale(I(weekhour**2)) \
                            + C(p_JFK) + C(p_LGA) + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1', data=df_copy)
res11 = model11.fit()
res11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                 7.020e+04
# Date:                Sat, 21 Oct 2017   Prob (F-statistic):               0.00
# Time:                        15:18:19   Log-Likelihood:            -4.9756e+06
# No. Observations:              683021   AIC:                         9.951e+06
# Df Residuals:                  683004   BIC:                         9.951e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# C(is_hol)[False]          805.5286      0.452   1781.544      0.000     804.642     806.415
# C(is_hol)[True]           706.3780      2.977    237.258      0.000     700.543     712.213
# C(p_JFK)[T.True]         -622.5136      4.622   -134.692      0.000    -631.572    -613.455
# C(p_LGA)[T.True]         -107.8115      3.094    -34.840      0.000    -113.877    -101.746
# C(d_JFK)[T.True]         -555.3204      6.744    -82.345      0.000    -568.538    -542.103
# C(d_LGA)[T.True]         -184.4412      4.405    -41.872      0.000    -193.074    -175.808
# scale(blizz)                1.0232      1.311      0.781      0.435      -1.546       3.592
# scale(I(weekhour ** 1))   121.9654      1.815     67.191      0.000     118.408     125.523
# scale(I(weekhour ** 2))  -151.5933      1.800    -84.201      0.000    -155.122    -148.065
# scale(total_dist)         500.3946      0.598    837.386      0.000     499.223     501.566
# scale(day_max_temp)       -45.8562      1.071    -42.799      0.000     -47.956     -43.756
# scale(day_rainfall)         4.1248      0.533      7.738      0.000       3.080       5.170
# scale(day_snowfall)        -1.2134      0.653     -1.858      0.063      -2.493       0.067
# scale(day_snowdepth)       21.7291      1.204     18.046      0.000      19.369      24.089
# scale(hr_temp)             68.0198      1.063     63.972      0.000      65.936      70.104
# scale(hr_humid)           -15.9612      0.495    -32.242      0.000     -16.932     -14.991
# scale(hr_windspeed)        12.1105      0.440     27.547      0.000      11.249      12.972
# ==============================================================================
# Omnibus:                   230238.699   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1669770.558
# Skew:                           1.435   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         24.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sm.stats.anova_lm(res00000, typ=2)
# Out:
#                             sum_sq        df             F         PR(>F)
# C(is_hol)             4.020879e+11       2.0  1.598974e+06   0.000000e+00
# C(p_JFK)              2.296462e+09       1.0  1.826458e+04   0.000000e+00
# C(p_LGA)              1.620611e+08       1.0  1.288929e+03  5.287033e-282
# C(d_JFK)              8.536360e+08       1.0  6.789270e+03   0.000000e+00
# C(d_LGA)              2.127030e+08       1.0  1.691702e+03   0.000000e+00
# scale(blizz)          3.425300e+05       1.0  2.724263e+00   9.883422e-02
# scale(weekhour)       4.415316e+08       1.0  3.511658e+03   0.000000e+00
# scale(total_dist)     8.717934e+10       1.0  6.933683e+05   0.000000e+00
# scale(day_max_temp)   2.988549e+08       1.0  2.376899e+03   0.000000e+00
# scale(day_rainfall)   6.515459e+05       1.0  5.181976e+00   2.282266e-02
# scale(day_snowfall)   2.196580e+06       1.0  1.747018e+01   2.918853e-05
# scale(day_snowdepth)  3.724239e+07       1.0  2.962019e+02   2.287167e-66
# scale(hr_temp)        6.388450e+08       1.0  5.080961e+03   0.000000e+00
# scale(hr_humid)       8.763059e+07       1.0  6.969572e+02  1.639703e-153
# scale(hr_windspeed)   8.066485e+07       1.0  6.415562e+02  1.782717e-141
# Residual              8.587634e+10  683005.0           NaN            NaN

# %% [markdown]
# ## cross validation

# %%
#df_copy.to_csv('../_data/train__dropped__shaved__cleaned__no_disaster.csv', index=False)

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

fmla_no_airport_no_blizz = 'dur1 ~ C(is_hol) + C(dow):C(hr) + scale(total_dist)\
             + scale(day_max_temp) + scale(day_rainfall)\
             + scale(day_snowfall) + scale(day_snowdepth)\
             + scale(hr_temp) + scale(hr_humid) + scale(hr_windspeed) - 1'

fmla_no_blizz = 'dur ~ C(is_hol) + C(dow):C(hr) + C(p_JFK) + C(p_LGA)\
                            + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1'

fmla = 'dur ~ scale(blizz) + C(is_hol) + C(dow):C(hr) + C(p_JFK) + C(p_LGA)\
                            + C(d_JFK) + C(d_LGA)\
                            + scale(total_dist) + scale(day_max_temp) + scale(day_rainfall)\
                            + scale(day_snowfall) + scale(day_snowdepth) + scale(hr_temp) + scale(hr_humid)\
                            + scale(hr_windspeed) - 1'

n = 3

cv = KFold(n)

scores = np.zeros(n)
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(df_copy.iloc[:, :-1], df_copy.iloc[:, -1], test_size=0.33)
    df_train = pd.concat([X_train, y_train], axis=1)
    print("trial {}".format(i+1))
    model_train = sm.OLS.from_formula(fmla, data=df_train)
    res_train = model_train.fit()
    y_pred = res_train.predict(X_test)
    y_pred[y_pred < 0] = 0
    try:
        scores[i] = mean_squared_log_error(y_test, y_pred)
        print(pd.concat([y_test, y_pred], axis=1).head(3))
    except:
        print("except")
        print(y_test[y_test<=0].shape)
        print(y_pred[y_pred<=0].shape)
        break

np.sqrt(scores)
# Out:
# trial 1
#          dur            0
# 360494    93   234.939545
# 137496  1864  1118.006389
# 162319   205   279.353012
# trial 2
#          dur            0
# 352877  2173  3185.134858
# 33006    668   673.915253
# 409736   193   488.097736
# trial 3
#          dur            0
# 374645   634   636.165195
# 185141  1142  1172.949954
# 61440    211   474.414115
# array([ 0.4778918 ,  0.48109985,  0.47856252])

# %%
from shapely.geometry

# %%
df_copy.iloc[61440]
# Out:
# is_hol                False
# blizz                     0
# m_d                     420
# dow               Wednesday
# hr                        7
# L2               0.00892686
# pas_cnt                   1
# p_JFK                 False
# p_LGA                 False
# d_JFK                 False
# d_LGA                 False
# total_dist           1576.7
# day_max_temp             69
# day_min_temp             49
# day_rainfall              0
# day_snowfall              0
# day_snowdepth             0
# hr_temp                  10
# hr_humid               0.36
# hr_dewpt               -4.4
# hr_windspeed            5.6
# hr_gustspeed              0
# hr_precip                 0
# dur                     211
# Name: 61440, dtype: object

# %%
np.sqrt(scores)
# Out:
# array([ 0.47922921,  0.47979153,  0.48086002,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold



cv = KFold(3)

scores = np.zeros(3)
for i in range(3):
    X_train, X_test, y_train, y_test = train_test_split(df_copy.iloc[:, :-1], df_copy.iloc[:, -1], test_size=0.33)
    df_train = pd.concat([X_train, y_train], axis=1)
    print("trial {}".format(i+1))
    model_train = model0 = sm.OLS.from_formula('dur1 ~ C(is_hol) + C(m_d) + C(dow) + C(hr) + C(pas_cnt)\
                            + scale(total_dist) + day_max_temp + day_min_temp + day_rainfall\
                            + day_snowfall + day_snowdepth + hr_temp + hr_humid + hr_dewpt\
                            + hr_windspeed + hr_gustspeed + hr_precip - 1', data=df_train)
    res_train = model_train.fit()
    y_pred = res_train.predict(X_test)
    y_pred[y_pred < 0] = 0
    try:
        scores[i] = mean_squared_log_error(y_test, y_pred)
        print(pd.concat([y_test, y_pred], axis=1).head(3))
    except:
        print("except")
        print(y_test[y_test<=0].shape)
        print(y_pred[y_pred<=0].shape)
        break

np.sqrt(scores)
# Out:
# trial 1
#         dur1            0
# 536428  1292  1054.850803
# 568864   645   887.577978
# 130365  1193   751.683572
# trial 2
#         dur1            0
# 693795   903   772.144072
# 46071   1265  1287.358821
# 496313   475   376.483320
# trial 3
#         dur1            0
# 140487   603   814.823659
# 5861     751   696.027557
# 257313   666  1014.085731
# array([ 0.48776671,  0.48784165,  0.4887244 ])

# %% [markdown]
# ### to add: dow, m_d, hr, L2, holiday, disaster
# ## * dow

# %%
s_dow = df_train['pickup_datetime'].apply(pd.to_datetime)

# %%
s_time = s_dow.copy()

# %%
s_dow = s_time.dt.weekday_name

# %%
df_train.insert(4, 'dow', s_dow)

# %%
df_train.head()
# Out:
#           id  vendor_id                 Time      pickup_datetime       dow  \
# 0  id3495688          1  2016-04-30 23:00:00  2016-04-30 23:59:00  Saturday
# 1  id3051282          1  2016-04-30 23:00:00  2016-04-30 23:59:00  Saturday
# 2  id0082851          1  2016-04-30 23:00:00  2016-04-30 23:59:00  Saturday
# 3  id0515725          2  2016-04-30 23:00:00  2016-04-30 23:58:00  Saturday
# 4  id1872374          2  2016-04-30 23:00:00  2016-04-30 23:58:00  Saturday
#
#   dropoff_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# 0      5/1/16 0:24                1        -73.987793        40.724792
# 1      5/1/16 0:22                1        -73.957596        40.717770
# 2      5/1/16 0:17                2        -74.000954        40.742031
# 3      5/1/16 0:12                1        -73.985733        40.738258
# 4      5/1/16 0:17                1        -74.006615        40.740650
#
#    dropoff_longitude  dropoff_latitude store_and_fwd_flag  trip_duration  \
# 0         -73.975616         40.656445                  N           1454
# 1         -73.951424         40.775230                  N           1409
# 2         -73.947708         40.782200                  N           1081
# 3         -73.993179         40.754890                  N            800
# 4         -73.985619         40.723362                  N           1151
#
#        starting_street        end_street  total_distance  total_travel_time  \
# 0      East 3rd Street    Sherman Street         10010.9              861.2
# 1     North 7th Street  East 83rd Street         10357.0              786.3
# 2           8th Avenue  East 93rd Street          9275.8              703.9
# 3  Gramercy Park North  West 37th Street          2726.9              298.0
# 4     West 13th Street          Avenue A          3455.8              458.2
#
#    number_of_steps                               street_for_each_step  \
# 0               17  East 3rd Street|2nd Avenue|Chrystie Street|Del...
# 1               15  North 7th Street|Roebling Street|North 10th St...
# 2               13  8th Avenue|West 36th Street|1st Avenue|1st Ave...
# 3                6  Gramercy Park North|East 21st Street|Park Aven...
# 4               10  West 13th Street|Washington Street|West 14th S...
#
#                                    distance_per_step  \
# 0  195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1  264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2  1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3                     65.8|76.6|955.9|326.7|1301.8|0
# 4  78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list  maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                   65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                   65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                   65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                   65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                   65
#
#    minimum temperature  average temperature  precipitation  snow fall  \
# 0                   46                 55.5            0.0        0.0
# 1                   46                 55.5            0.0        0.0
# 2                   46                 55.5            0.0        0.0
# 3                   46                 55.5            0.0        0.0
# 4                   46                 55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point Wind Dir  Wind Speed  Gust Speed  \
# 0         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 1         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 2         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 3         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 4         0.0   10.6      0.56        2.2      SSE        13.0         0.0
#
#    Precip Events Conditions
# 0     0.0   None      Clear
# 1     0.0   None      Clear
# 2     0.0   None      Clear
# 3     0.0   None      Clear
# 4     0.0   None      Clear

# %%
df_copy = df_train

# %% [markdown]
# ## * m_d

# %%
df_copy['pickup_datetime'] = df_copy['pickup_datetime'].apply(pd.to_datetime)

# %%
df_copy.insert(loc=4, column='m_d', value=np.vectorize(str)(df_copy['pickup_datetime'].dt.month*100
                                                             + df_copy['pickup_datetime'].dt.day))

# %%
df_copy.head()
# Out:
#           id  vendor_id                 Time     pickup_datetime  m_d  \
# 0  id3495688          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 1  id3051282          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 2  id0082851          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 3  id0515725          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
# 4  id1872374          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
#
#         dow dropoff_datetime  passenger_count  pickup_longitude  \
# 0  Saturday      5/1/16 0:24                1        -73.987793
# 1  Saturday      5/1/16 0:22                1        -73.957596
# 2  Saturday      5/1/16 0:17                2        -74.000954
# 3  Saturday      5/1/16 0:12                1        -73.985733
# 4  Saturday      5/1/16 0:17                1        -74.006615
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0        40.724792         -73.975616         40.656445                  N
# 1        40.717770         -73.951424         40.775230                  N
# 2        40.742031         -73.947708         40.782200                  N
# 3        40.738258         -73.993179         40.754890                  N
# 4        40.740650         -73.985619         40.723362                  N
#
#    trip_duration      starting_street        end_street  total_distance  \
# 0           1454      East 3rd Street    Sherman Street         10010.9
# 1           1409     North 7th Street  East 83rd Street         10357.0
# 2           1081           8th Avenue  East 93rd Street          9275.8
# 3            800  Gramercy Park North  West 37th Street          2726.9
# 4           1151     West 13th Street          Avenue A          3455.8
#
#    total_travel_time  number_of_steps  \
# 0              861.2               17
# 1              786.3               15
# 2              703.9               13
# 3              298.0                6
# 4              458.2               10
#
#                                 street_for_each_step  \
# 0  East 3rd Street|2nd Avenue|Chrystie Street|Del...
# 1  North 7th Street|Roebling Street|North 10th St...
# 2  8th Avenue|West 36th Street|1st Avenue|1st Ave...
# 3  Gramercy Park North|East 21st Street|Park Aven...
# 4  West 13th Street|Washington Street|West 14th S...
#
#                                    distance_per_step  \
# 0  195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1  264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2  1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3                     65.8|76.6|955.9|326.7|1301.8|0
# 4  78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list  maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                   65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                   65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                   65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                   65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                   65
#
#    minimum temperature  average temperature  precipitation  snow fall  \
# 0                   46                 55.5            0.0        0.0
# 1                   46                 55.5            0.0        0.0
# 2                   46                 55.5            0.0        0.0
# 3                   46                 55.5            0.0        0.0
# 4                   46                 55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point Wind Dir  Wind Speed  Gust Speed  \
# 0         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 1         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 2         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 3         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 4         0.0   10.6      0.56        2.2      SSE        13.0         0.0
#
#    Precip Events Conditions
# 0     0.0   None      Clear
# 1     0.0   None      Clear
# 2     0.0   None      Clear
# 3     0.0   None      Clear
# 4     0.0   None      Clear

# %% [markdown]
# ## * hr

# %%
df_copy.insert(loc=6, column='hr', value=df_copy['pickup_datetime'].dt.hour)

# %%
df_copy.head()
# Out:
#           id  vendor_id                 Time     pickup_datetime  m_d  \
# 0  id3495688          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 1  id3051282          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 2  id0082851          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 3  id0515725          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
# 4  id1872374          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
#
#         dow  hr dropoff_datetime  passenger_count  pickup_longitude  \
# 0  Saturday  23      5/1/16 0:24                1        -73.987793
# 1  Saturday  23      5/1/16 0:22                1        -73.957596
# 2  Saturday  23      5/1/16 0:17                2        -74.000954
# 3  Saturday  23      5/1/16 0:12                1        -73.985733
# 4  Saturday  23      5/1/16 0:17                1        -74.006615
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0        40.724792         -73.975616         40.656445                  N
# 1        40.717770         -73.951424         40.775230                  N
# 2        40.742031         -73.947708         40.782200                  N
# 3        40.738258         -73.993179         40.754890                  N
# 4        40.740650         -73.985619         40.723362                  N
#
#    trip_duration      starting_street        end_street  total_distance  \
# 0           1454      East 3rd Street    Sherman Street         10010.9
# 1           1409     North 7th Street  East 83rd Street         10357.0
# 2           1081           8th Avenue  East 93rd Street          9275.8
# 3            800  Gramercy Park North  West 37th Street          2726.9
# 4           1151     West 13th Street          Avenue A          3455.8
#
#    total_travel_time  number_of_steps    ...      \
# 0              861.2               17    ...
# 1              786.3               15    ...
# 2              703.9               13    ...
# 3              298.0                6    ...
# 4              458.2               10    ...
#
#                                    distance_per_step  \
# 0  195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1  264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2  1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3                     65.8|76.6|955.9|326.7|1301.8|0
# 4  78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                  65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                  65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                  65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                  65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                  65
#
#    minimum temperature  average temperature  precipitation  snow fall  \
# 0                   46                 55.5            0.0        0.0
# 1                   46                 55.5            0.0        0.0
# 2                   46                 55.5            0.0        0.0
# 3                   46                 55.5            0.0        0.0
# 4                   46                 55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point  Wind Dir Wind Speed  Gust Speed  \
# 0         0.0   10.6      0.56        2.2       SSE       13.0         0.0
# 1         0.0   10.6      0.56        2.2       SSE       13.0         0.0
# 2         0.0   10.6      0.56        2.2       SSE       13.0         0.0
# 3         0.0   10.6      0.56        2.2       SSE       13.0         0.0
# 4         0.0   10.6      0.56        2.2       SSE       13.0         0.0
#
#    Precip  Events Conditions
# 0     0.0    None      Clear
# 1     0.0    None      Clear
# 2     0.0    None      Clear
# 3     0.0    None      Clear
# 4     0.0    None      Clear
#
# [5 rows x 41 columns]

# %% [markdown]
# ## * L2

# %%
def dist(plng, plat, dlng, dlat):
    return ((dlng-plng)**2 + (dlat-plat)**2) ** 0.5

# %%
df_copy.insert(loc=7, column='L2', value=np.vectorize(dist)(\
                df_copy['pickup_longitude'], df_copy['pickup_latitude'],\
                df_copy['dropoff_longitude'], df_copy['dropoff_latitude']))

df_copy.head()
# Out:
#           id  vendor_id                 Time     pickup_datetime  m_d  \
# 0  id3495688          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 1  id3051282          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 2  id0082851          1  2016-04-30 23:00:00 2016-04-30 23:59:00  430
# 3  id0515725          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
# 4  id1872374          2  2016-04-30 23:00:00 2016-04-30 23:58:00  430
#
#         dow  hr        L2 dropoff_datetime  passenger_count  pickup_longitude  \
# 0  Saturday  23  0.069424      5/1/16 0:24                1        -73.987793
# 1  Saturday  23  0.057791      5/1/16 0:22                1        -73.957596
# 2  Saturday  23  0.066698      5/1/16 0:17                2        -74.000954
# 3  Saturday  23  0.018223      5/1/16 0:12                1        -73.985733
# 4  Saturday  23  0.027198      5/1/16 0:17                1        -74.006615
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0        40.724792         -73.975616         40.656445                  N
# 1        40.717770         -73.951424         40.775230                  N
# 2        40.742031         -73.947708         40.782200                  N
# 3        40.738258         -73.993179         40.754890                  N
# 4        40.740650         -73.985619         40.723362                  N
#
#    trip_duration      starting_street        end_street  total_distance  \
# 0           1454      East 3rd Street    Sherman Street         10010.9
# 1           1409     North 7th Street  East 83rd Street         10357.0
# 2           1081           8th Avenue  East 93rd Street          9275.8
# 3            800  Gramercy Park North  West 37th Street          2726.9
# 4           1151     West 13th Street          Avenue A          3455.8
#
#    total_travel_time     ...      \
# 0              861.2     ...
# 1              786.3     ...
# 2              703.9     ...
# 3              298.0     ...
# 4              458.2     ...
#
#                                    distance_per_step  \
# 0  195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1  264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2  1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3                     65.8|76.6|955.9|326.7|1301.8|0
# 4  78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                  65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                  65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                  65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                  65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                  65
#
#   minimum temperature  average temperature  precipitation  snow fall  \
# 0                  46                 55.5            0.0        0.0
# 1                  46                 55.5            0.0        0.0
# 2                  46                 55.5            0.0        0.0
# 3                  46                 55.5            0.0        0.0
# 4                  46                 55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point  Wind Dir  Wind Speed Gust Speed  \
# 0         0.0   10.6      0.56        2.2       SSE        13.0        0.0
# 1         0.0   10.6      0.56        2.2       SSE        13.0        0.0
# 2         0.0   10.6      0.56        2.2       SSE        13.0        0.0
# 3         0.0   10.6      0.56        2.2       SSE        13.0        0.0
# 4         0.0   10.6      0.56        2.2       SSE        13.0        0.0
#
#    Precip  Events  Conditions
# 0     0.0    None       Clear
# 1     0.0    None       Clear
# 2     0.0    None       Clear
# 3     0.0    None       Clear
# 4     0.0    None       Clear
#
# [5 rows x 42 columns]

# %% [markdown]
# ## * holiday

# %%
holidays = {(2016, 1, 1) : 'New Year\'s',
            (2016, 1, 18) : 'MLK',
            (2016, 2, 15) : 'Washington',
            (2016, 5, 30) : 'Memorial' }

def is_holiday(timestamp):
    return (timestamp.year, timestamp.month, timestamp.day) in holidays

t = pd.Timestamp(2016, 5, 30)

print(is_holiday(t))
# Out:
# True

# %%
s_hol = df_copy['pickup_datetime'].apply(is_holiday)
s_hol.sum()
# Out:
# 15583

# %%
df_copy.insert(loc=4, column='is_hol', value=s_hol)

# %%
df_copy.head()
# Out:
#           id  vendor_id                 Time     pickup_datetime  is_hol  m_d  \
# 0  id3495688          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 1  id3051282          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 2  id0082851          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 3  id0515725          2  2016-04-30 23:00:00 2016-04-30 23:58:00   False  430
# 4  id1872374          2  2016-04-30 23:00:00 2016-04-30 23:58:00   False  430
#
#         dow  hr        L2 dropoff_datetime  passenger_count  pickup_longitude  \
# 0  Saturday  23  0.069424      5/1/16 0:24                1        -73.987793
# 1  Saturday  23  0.057791      5/1/16 0:22                1        -73.957596
# 2  Saturday  23  0.066698      5/1/16 0:17                2        -74.000954
# 3  Saturday  23  0.018223      5/1/16 0:12                1        -73.985733
# 4  Saturday  23  0.027198      5/1/16 0:17                1        -74.006615
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0        40.724792         -73.975616         40.656445                  N
# 1        40.717770         -73.951424         40.775230                  N
# 2        40.742031         -73.947708         40.782200                  N
# 3        40.738258         -73.993179         40.754890                  N
# 4        40.740650         -73.985619         40.723362                  N
#
#    trip_duration      starting_street        end_street  total_distance  \
# 0           1454      East 3rd Street    Sherman Street         10010.9
# 1           1409     North 7th Street  East 83rd Street         10357.0
# 2           1081           8th Avenue  East 93rd Street          9275.8
# 3            800  Gramercy Park North  West 37th Street          2726.9
# 4           1151     West 13th Street          Avenue A          3455.8
#
#       ...                                      distance_per_step  \
# 0     ...      195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1     ...      264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2     ...      1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3     ...                         65.8|76.6|955.9|326.7|1301.8|0
# 4     ...      78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                  65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                  65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                  65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                  65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                  65
#
#   minimum temperature average temperature  precipitation  snow fall  \
# 0                  46                55.5            0.0        0.0
# 1                  46                55.5            0.0        0.0
# 2                  46                55.5            0.0        0.0
# 3                  46                55.5            0.0        0.0
# 4                  46                55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point  Wind Dir  Wind Speed  Gust Speed  \
# 0         0.0   10.6      0.56        2.2       SSE        13.0         0.0
# 1         0.0   10.6      0.56        2.2       SSE        13.0         0.0
# 2         0.0   10.6      0.56        2.2       SSE        13.0         0.0
# 3         0.0   10.6      0.56        2.2       SSE        13.0         0.0
# 4         0.0   10.6      0.56        2.2       SSE        13.0         0.0
#
#   Precip  Events  Conditions
# 0    0.0    None       Clear
# 1    0.0    None       Clear
# 2    0.0    None       Clear
# 3    0.0    None       Clear
# 4    0.0    None       Clear
#
# [5 rows x 43 columns]

# %% [markdown]
# ## * disaster

# %% [markdown]
# ??

# %%
df_copy.to_csv('../_data/train_with__all_data_no_disaster_nans_fixed.csv', index=False)

# %% [markdown]
# ---

# %%
pd.options.display.max_columns = 60

# %%
df_copy.head()
# Out:
#           id  vendor_id                 Time     pickup_datetime  is_hol  m_d  \
# 0  id3495688          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 1  id3051282          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 2  id0082851          1  2016-04-30 23:00:00 2016-04-30 23:59:00   False  430
# 3  id0515725          2  2016-04-30 23:00:00 2016-04-30 23:58:00   False  430
# 4  id1872374          2  2016-04-30 23:00:00 2016-04-30 23:58:00   False  430
#
#         dow  hr        L2 dropoff_datetime  passenger_count  pickup_longitude  \
# 0  Saturday  23  0.069424      5/1/16 0:24                1        -73.987793
# 1  Saturday  23  0.057791      5/1/16 0:22                1        -73.957596
# 2  Saturday  23  0.066698      5/1/16 0:17                2        -74.000954
# 3  Saturday  23  0.018223      5/1/16 0:12                1        -73.985733
# 4  Saturday  23  0.027198      5/1/16 0:17                1        -74.006615
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 0        40.724792         -73.975616         40.656445                  N
# 1        40.717770         -73.951424         40.775230                  N
# 2        40.742031         -73.947708         40.782200                  N
# 3        40.738258         -73.993179         40.754890                  N
# 4        40.740650         -73.985619         40.723362                  N
#
#    trip_duration      starting_street        end_street  total_distance  \
# 0           1454      East 3rd Street    Sherman Street         10010.9
# 1           1409     North 7th Street  East 83rd Street         10357.0
# 2           1081           8th Avenue  East 93rd Street          9275.8
# 3            800  Gramercy Park North  West 37th Street          2726.9
# 4           1151     West 13th Street          Avenue A          3455.8
#
#    total_travel_time  number_of_steps  \
# 0              861.2               17
# 1              786.3               15
# 2              703.9               13
# 3              298.0                6
# 4              458.2               10
#
#                                 street_for_each_step  \
# 0  East 3rd Street|2nd Avenue|Chrystie Street|Del...
# 1  North 7th Street|Roebling Street|North 10th St...
# 2  8th Avenue|West 36th Street|1st Avenue|1st Ave...
# 3  Gramercy Park North|East 21st Street|Park Aven...
# 4  West 13th Street|Washington Street|West 14th S...
#
#                                    distance_per_step  \
# 0  195.7|229|437.7|102.6|12.3|488.4|2311.3|1494.7...
# 1  264.2|238.3|713|319.8|629.2|1747.4|1285.8|549....
# 2  1457.9|1924|350.4|16.8|457.9|120.6|409.2|3653....
# 3                     65.8|76.6|955.9|326.7|1301.8|0
# 4  78.8|87.7|702.9|608.4|34.4|367.5|304.2|1151.6|...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list  maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                   65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                   65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                   65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                   65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                   65
#
#    minimum temperature  average temperature  precipitation  snow fall  \
# 0                   46                 55.5            0.0        0.0
# 1                   46                 55.5            0.0        0.0
# 2                   46                 55.5            0.0        0.0
# 3                   46                 55.5            0.0        0.0
# 4                   46                 55.5            0.0        0.0
#
#    snow depth  Temp.  Humidity  Dew Point Wind Dir  Wind Speed  Gust Speed  \
# 0         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 1         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 2         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 3         0.0   10.6      0.56        2.2      SSE        13.0         0.0
# 4         0.0   10.6      0.56        2.2      SSE        13.0         0.0
#
#    Precip Events Conditions
# 0     0.0   None      Clear
# 1     0.0   None      Clear
# 2     0.0   None      Clear
# 3     0.0   None      Clear
# 4     0.0   None      Clear

# %%
droppable = ['id', 'vendor_id', 'Time', 'pickup_datetime', 'dropoff_datetime',\
             'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',\
             'store_and_fwd_flag', 'starting_street', 'end_street',\
             'number_of_steps', 'street_for_each_step', 'distance_per_step', 'travel_time_per_step',\
             'step_maneuvers', 'step_direction', 'step_location_list',\
             'average temperature', 'Wind Dir', 'Events', 'Conditions']

# %%
for col in droppable:
    del df_copy[col]

# %%
df_copy.head()
# Out:
#    is_hol  m_d       dow  hr        L2  passenger_count  trip_duration  \
# 0   False  430  Saturday  23  0.069424                1           1454
# 1   False  430  Saturday  23  0.057791                1           1409
# 2   False  430  Saturday  23  0.066698                2           1081
# 3   False  430  Saturday  23  0.018223                1            800
# 4   False  430  Saturday  23  0.027198                1           1151
#
#    total_distance  total_travel_time  maximum temperature  \
# 0         10010.9              861.2                   65
# 1         10357.0              786.3                   65
# 2          9275.8              703.9                   65
# 3          2726.9              298.0                   65
# 4          3455.8              458.2                   65
#
#    minimum temperature  precipitation  snow fall  snow depth  Temp.  Humidity  \
# 0                   46            0.0        0.0         0.0   10.6      0.56
# 1                   46            0.0        0.0         0.0   10.6      0.56
# 2                   46            0.0        0.0         0.0   10.6      0.56
# 3                   46            0.0        0.0         0.0   10.6      0.56
# 4                   46            0.0        0.0         0.0   10.6      0.56
#
#    Dew Point  Wind Speed  Gust Speed  Precip
# 0        2.2        13.0         0.0     0.0
# 1        2.2        13.0         0.0     0.0
# 2        2.2        13.0         0.0     0.0
# 3        2.2        13.0         0.0     0.0
# 4        2.2        13.0         0.0     0.0

# %%
df_copy.to_csv('../_data/train__dropped__no_disaster.csv', index=False)

# %%
df_copy.columns
# Out:
# Index(['is_hol', 'm_d', 'dow', 'hr', 'L2', 'passenger_count', 'trip_duration',
#        'total_distance', 'total_travel_time', 'maximum temperature',
#        'minimum temperature', 'precipitation', 'snow fall', 'snow depth',
#        'Temp.', 'Humidity', 'Dew Point', 'Wind Speed', 'Gust Speed', 'Precip'],
#       dtype='object')

# %%
short_cols = ['is_hol', 'm_d', 'dow', 'hr', 'L2', 'pas_cnt', 'dur',
       'total_dist', 'total_time', 'day_max_temp',
       'day_min_temp', 'day_rainfall', 'day_snowfall', 'day_snowdepth',
       'hr_temp', 'hr_humid', 'hr_dewpt', 'hr_windspeed', 'hr_gustspeed', 'hr_precip']

# %%
df_copy.columns = short_cols

# %%
df_copy.head()
# Out:
#    is_hol  m_d       dow  hr        L2  pas_cnt   dur  total_dist  total_time  \
# 0   False  430  Saturday  23  0.069424        1  1454     10010.9       861.2
# 1   False  430  Saturday  23  0.057791        1  1409     10357.0       786.3
# 2   False  430  Saturday  23  0.066698        2  1081      9275.8       703.9
# 3   False  430  Saturday  23  0.018223        1   800      2726.9       298.0
# 4   False  430  Saturday  23  0.027198        1  1151      3455.8       458.2
#
#    day_max_temp  day_min_temp  day_rainfall  day_snowfall  day_snowdepth  \
# 0            65            46           0.0           0.0            0.0
# 1            65            46           0.0           0.0            0.0
# 2            65            46           0.0           0.0            0.0
# 3            65            46           0.0           0.0            0.0
# 4            65            46           0.0           0.0            0.0
#
#    hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip
# 0     10.6      0.56       2.2          13.0           0.0        0.0
# 1     10.6      0.56       2.2          13.0           0.0        0.0
# 2     10.6      0.56       2.2          13.0           0.0        0.0
# 3     10.6      0.56       2.2          13.0           0.0        0.0
# 4     10.6      0.56       2.2          13.0           0.0        0.0

# %%
df_copy.isnull().sum()
# Out:
# is_hol              0
# m_d                 0
# dow                 0
# hr                  0
# L2                  0
# pas_cnt             0
# dur                 0
# total_dist          0
# total_time          0
# day_max_temp        0
# day_min_temp        0
# day_rainfall        0
# day_snowfall        0
# day_snowdepth       0
# hr_temp          5293
# hr_humid         5293
# hr_dewpt         5293
# hr_windspeed     5293
# hr_gustspeed     5293
# hr_precip        5293
# dtype: int64

# %%
nans = df_copy.loc[df_copy['hr_temp'].isnull(), ['m_d', 'hr']].copy()
nans['m_d'] = nans['m_d'].apply(int)
print(nans.head())
nansarray = np.array(nans)
np.unique(nansarray, axis=0)
# Out:
#        m_d  hr
# 67827  419  11
# 67828  419  11
# 67829  419  11
# 67830  419  11
# 67831  419  11
# array([[313,   4],
#        [105,   0],
#        [105,   1],
#        [105,   2],
#        [105,   3],
#        [108,  10],
#        [401,   8],
#        [401,   9],
#        [401,  10],
#        [401,  11],
#        [401,  12],
#        [401,  13],
#        [401,  14],
#        [402,   8],
#        [403,   0],
#        [403,   1],
#        [404,   0],
#        [404,   2],
#        [409,   6],
#        [413,  22],
#        [413,  23],
#        [416,   0],
#        [419,  11],
#        [202,  23]], dtype=int64)

# %%
nan_pairs = np.unique(nansarray, axis=0)

nan_pairs
# Out:
# array([[313,   4],
#        [105,   0],
#        [105,   1],
#        [105,   2],
#        [105,   3],
#        [108,  10],
#        [401,   8],
#        [401,   9],
#        [401,  10],
#        [401,  11],
#        [401,  12],
#        [401,  13],
#        [401,  14],
#        [402,   8],
#        [403,   0],
#        [403,   1],
#        [404,   0],
#        [404,   2],
#        [409,   6],
#        [413,  22],
#        [413,  23],
#        [416,   0],
#        [419,  11],
#        [202,  23]], dtype=int64)

# %%
df_copy2 = df_copy.copy()

# %%
def get_prev(md, hr):
    m = int(md[0])
    d = int(md[1:])
    ts = pd.Timestamp(2016, m, d, hr, 0, 0)
    ts -= pd.Timedelta(hours=1)
    m_new = ts.month
    d_new = ts.day
    hr_new = ts.hour
    md_new = str(m_new)+'{:02}'.format(d_new)
    return(md_new, hr_new)

def get_next(m_d, hr):
    m = int(m_d[0])
    d = int(m_d[1:])
    ts = pd.Timestamp(2016, m, d, hr, 0, 0)
    ts += pd.Timedelta(hours=1)
    m_new = ts.month
    d_new = ts.day
    hr_new = ts.hour
    m_d_new = str(m_new)+'{:02}'.format(d_new)
    return(m_d_new, hr_new)

get_prev('105', 0)
get_next('630', 23)
# Out:
# ('701', 0)

# %%
df_copy2['hr_temp'][(df_copy2['m_d'] == md_prev) & (df_copy2['hr'] == hr_prev)].iloc[0]
# Out:
# 6.7000000000000002

# %%
fill_cols = ['hr_temp', 'hr_humid', 'hr_dewpt', 'hr_windspeed', 'hr_gustspeed', 'hr_precip']

for md, hr in nan_pairs:
    print(md, hr)
    md = str(md)
    md_prev, hr_prev = md, hr
    md_next, hr_next = md, hr
    while df_copy2[col][(df_copy2['m_d'] == md_prev) & (df_copy2['hr'] == hr_prev)].isnull().sum() > 0:
        md_prev, hr_prev = get_prev(md_prev, hr_prev)
    while df_copy2[col][(df_copy2['m_d'] == md_next) & (df_copy2['hr'] == hr_next)].isnull().sum() > 0:
        md_next, hr_next = get_next(md_next, hr_next)

    for col in fill_cols:
        print(col)
        col_prev = df_copy2[col][(df_copy2['m_d'] == md_prev) & (df_copy2['hr'] == hr_prev)].iloc[0]
        col_next = df_copy2[col][(df_copy2['m_d'] == md_next) & (df_copy2['hr'] == hr_next)].iloc[0]
        col_new = np.average([col_prev, col_next])
        print(col_new)
        df_copy2.loc[(df_copy2['m_d'] == md) & (df_copy2['hr'] == hr), col] = col_new
    print()
# Out:
# 313 4
# hr_temp
# 11.1
# hr_humid
# 0.59
# hr_dewpt
# 3.3
# hr_windspeed
# 0.0
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 105 0
# hr_temp
# -9.7
# hr_humid
# 0.515
# hr_dewpt
# -18.05
# hr_windspeed
# 11.1
# hr_gustspeed
# 33.3
# hr_precip
# 0.0
#
# 105 1
# hr_temp
# -10.4
# hr_humid
# 0.5375
# hr_dewpt
# -18.175
# hr_windspeed
# 9.25
# hr_gustspeed
# 33.3
# hr_precip
# 0.0
#
# 105 2
# hr_temp
# -10.75
# hr_humid
# 0.54875
# hr_dewpt
# -18.2375
# hr_windspeed
# 8.325
# hr_gustspeed
# 33.3
# hr_precip
# 0.0
#
# 105 3
# hr_temp
# -10.925
# hr_humid
# 0.554375
# hr_dewpt
# -18.26875
# hr_windspeed
# 7.8625
# hr_gustspeed
# 33.3
# hr_precip
# 0.0
#
# 108 10
# hr_temp
# 3.5
# hr_humid
# 0.65
# hr_dewpt
# -2.5
# hr_windspeed
# 0.0
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 8
# hr_temp
# 20.0
# hr_humid
# 0.68
# hr_dewpt
# 13.85
# hr_windspeed
# 4.65
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 9
# hr_temp
# 21.1
# hr_humid
# 0.645
# hr_dewpt
# 14.125
# hr_windspeed
# 2.325
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 10
# hr_temp
# 21.65
# hr_humid
# 0.6275
# hr_dewpt
# 14.2625
# hr_windspeed
# 1.1625
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 11
# hr_temp
# 21.925
# hr_humid
# 0.61875
# hr_dewpt
# 14.33125
# hr_windspeed
# 0.58125
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 12
# hr_temp
# 22.0625
# hr_humid
# 0.614375
# hr_dewpt
# 14.365625
# hr_windspeed
# 0.290625
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 13
# hr_temp
# 22.13125
# hr_humid
# 0.6121875
# hr_dewpt
# 14.3828125
# hr_windspeed
# 0.1453125
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 401 14
# hr_temp
# 22.165625
# hr_humid
# 0.61109375
# hr_dewpt
# 14.39140625
# hr_windspeed
# 0.07265625
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 402 8
# hr_temp
# 12.2
# hr_humid
# 0.675
# hr_dewpt
# 6.4
# hr_windspeed
# 4.65
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 403 0
# hr_temp
# 10.3
# hr_humid
# 0.77
# hr_dewpt
# 6.4
# hr_windspeed
# 6.5
# hr_gustspeed
# 15.75
# hr_precip
# 0.0
#
# 403 1
# hr_temp
# 10.15
# hr_humid
# 0.785
# hr_dewpt
# 6.55
# hr_windspeed
# 3.25
# hr_gustspeed
# 7.875
# hr_precip
# 0.0
#
# 404 0
# hr_temp
# 3.3
# hr_humid
# 0.31
# hr_dewpt
# -12.5
# hr_windspeed
# 7.4
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 404 2
# hr_temp
# 3.05
# hr_humid
# 0.365
# hr_dewpt
# -10.8
# hr_windspeed
# 9.25
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 409 6
# hr_temp
# 3.3
# hr_humid
# 0.44
# hr_dewpt
# -8.05
# hr_windspeed
# 5.6
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 413 22
# hr_temp
# 9.15
# hr_humid
# 0.475
# hr_dewpt
# -1.65
# hr_windspeed
# 2.8
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 413 23
# hr_temp
# 8.725
# hr_humid
# 0.5175
# hr_dewpt
# -0.825
# hr_windspeed
# 1.4
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 416 0
# hr_temp
# 8.6
# hr_humid
# 0.595
# hr_dewpt
# 1.15
# hr_windspeed
# 2.8
# hr_gustspeed
# 0.0
# hr_precip
# 0.0
#
# 419 11
# hr_temp
# 19.45
# hr_humid
# 0.375
# hr_dewpt
# 4.7
# hr_windspeed
# 7.4
# hr_gustspeed
# 13.9
# hr_precip
# 0.0
#
# 202 23
# hr_temp
# 6.4
# hr_humid
# 0.545
# hr_dewpt
# -2.2
# hr_windspeed
# 2.8
# hr_gustspeed
# 0.0
# hr_precip
# 0.0

# %%
df_copy2.head()
# Out:
#    is_hol  m_d       dow  hr        L2  pas_cnt   dur  total_dist  total_time  \
# 0   False  430  Saturday  23  0.069424        1  1454     10010.9       861.2
# 1   False  430  Saturday  23  0.057791        1  1409     10357.0       786.3
# 2   False  430  Saturday  23  0.066698        2  1081      9275.8       703.9
# 3   False  430  Saturday  23  0.018223        1   800      2726.9       298.0
# 4   False  430  Saturday  23  0.027198        1  1151      3455.8       458.2
#
#    day_max_temp  day_min_temp  day_rainfall  day_snowfall  day_snowdepth  \
# 0            65            46           0.0           0.0            0.0
# 1            65            46           0.0           0.0            0.0
# 2            65            46           0.0           0.0            0.0
# 3            65            46           0.0           0.0            0.0
# 4            65            46           0.0           0.0            0.0
#
#    hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip
# 0     10.6      0.56       2.2          13.0           0.0        0.0
# 1     10.6      0.56       2.2          13.0           0.0        0.0
# 2     10.6      0.56       2.2          13.0           0.0        0.0
# 3     10.6      0.56       2.2          13.0           0.0        0.0
# 4     10.6      0.56       2.2          13.0           0.0        0.0

# %%
df_copy2.to_csv('../_data/train__dropped__no_disaster_nan_fixed.csv', index=False)

# %%
df_copy3 = df_copy2.copy()
df_copy3.isnull().sum()
# Out:
# is_hol           0
# m_d              0
# dow              0
# hr               0
# L2               0
# pas_cnt          0
# dur              0
# total_dist       0
# total_time       0
# day_max_temp     0
# day_min_temp     0
# day_rainfall     0
# day_snowfall     0
# day_snowdepth    0
# hr_temp          0
# hr_humid         0
# hr_dewpt         0
# hr_windspeed     0
# hr_gustspeed     0
# hr_precip        0
# dtype: int64

# %%
md = '419'
hr = 11
df_copy2.loc[(df_copy2['m_d'] == md) & (df_copy2['hr'] == hr), 'hr_temp'].head()
# Out:
# 67827    19.45
# 67828    19.45
# 67829    19.45
# 67830    19.45
# 67831    19.45
# Name: hr_temp, dtype: float64

# %%
df_copy3.loc[(df_copy2['m_d'] == md) & (df_copy2['hr'] == hr), 'hr_temp'] = 3
df_copy3.loc[(df_copy2['m_d'] == md) & (df_copy2['hr'] == hr), 'hr_temp'].head()
# Out:
# 67827    3.0
# 67828    3.0
# 67829    3.0
# 67830    3.0
# 67831    3.0
# Name: hr_temp, dtype: float64

# %%
ssss[:]
# Out:
# 67827   NaN
# 67828   NaN
# 67829   NaN
# 67830   NaN
# 67831   NaN
# 67832   NaN
# 67833   NaN
# 67834   NaN
# 67835   NaN
# 67836   NaN
# 67837   NaN
# 67838   NaN
# 67839   NaN
# 67840   NaN
# 67841   NaN
# 67842   NaN
# 67843   NaN
# 67844   NaN
# 67845   NaN
# 67846   NaN
# 67847   NaN
# 67848   NaN
# 67849   NaN
# 67850   NaN
# 67851   NaN
# 67852   NaN
# 67853   NaN
# 67854   NaN
# 67855   NaN
# 67856   NaN
#          ..
# 68066   NaN
# 68067   NaN
# 68068   NaN
# 68069   NaN
# 68070   NaN
# 68071   NaN
# 68072   NaN
# 68073   NaN
# 68074   NaN
# 68075   NaN
# 68076   NaN
# 68077   NaN
# 68078   NaN
# 68079   NaN
# 68080   NaN
# 68081   NaN
# 68082   NaN
# 68083   NaN
# 68084   NaN
# 68085   NaN
# 68086   NaN
# 68087   NaN
# 68088   NaN
# 68089   NaN
# 68090   NaN
# 68091   NaN
# 68092   NaN
# 68093   NaN
# 68094   NaN
# 68095   NaN
# Name: hr_temp, Length: 269, dtype: float64

# %%
df_copy.to_csv('../_data/train__dropped__no_disaster.csv', index=False)

# %%
def make_hourly(timestamp):
    y = timestamp.year
    m = timestamp.month
    d = timestamp.day
    h = timestamp.hour
    return pd.Timestamp(y, m, d, h, 0, 0)

# %%
df_copy.insert(2, 'Time', df_copy['pickup_datetime'].apply(make_hourly))

# %%
del df_copy['pickup_hour']

# %%
df_copy.head()
# Out:
#           id  vendor_id                Time     pickup_datetime  \
# 0  id3495688          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 1  id3051282          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 2  id0082851          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 3  id0515725          2 2016-04-30 23:00:00 2016-04-30 23:58:00
# 4  id1872374          2 2016-04-30 23:00:00 2016-04-30 23:58:00
#
#   dropoff_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# 0      5/1/16 0:24                1        -73.987793        40.724792
# 1      5/1/16 0:22                1        -73.957596        40.717770
# 2      5/1/16 0:17                2        -74.000954        40.742031
# 3      5/1/16 0:12                1        -73.985733        40.738258
# 4      5/1/16 0:17                1        -74.006615        40.740650
#
#    dropoff_longitude  dropoff_latitude    ...      \
# 0         -73.975616         40.656445    ...
# 1         -73.951424         40.775230    ...
# 2         -73.947708         40.782200    ...
# 3         -73.993179         40.754890    ...
# 4         -73.985619         40.723362    ...
#
#                                 travel_time_per_step  \
# 0  29.4|31.7|59|13.4|5.9|64.5|179.3|105.2|211.3|9...
# 1  43.4|39.6|48.8|20.9|43.1|104|92.1|29.2|55.7|10...
# 2  197.4|155.4|27.5|0.9|35.2|10.8|32.8|135.2|20.7...
# 3                           7.4|12.7|129|49.8|99.1|0
# 4     10.9|13.9|89.4|85.2|5.8|45.2|38.1|150.9|18.8|0
#
#                                       step_maneuvers  \
# 0  depart|turn|new name|turn|turn|turn|turn|new n...
# 1  depart|turn|turn|turn|new name|turn|new name|t...
# 2  depart|turn|turn|fork|fork|fork|on ramp|merge|...
# 3                  depart|turn|turn|fork|turn|arrive
# 4  depart|turn|turn|turn|turn|continue|new name|t...
#
#                                       step_direction  \
# 0  right|left|straight|right|slight right|left|sl...
# 1  none|left|left|right|straight|right|straight|l...
# 2  left|right|left|slight left|slight left|slight...
# 3       none|straight|right|slight right|left|arrive
# 4  right|right|right|right|left|straight|straight...
#
#                                   step_location_list  maximum temperature  \
# 0  -73.987841,40.724727|-73.98987,40.725582|-73.9...                   65
# 1  -73.957606,40.717761|-73.955186,40.716252|-73....                   65
# 2  -74.000886,40.742003|-73.992525,40.753478|-73....                   65
# 3  -73.985741,40.738246|-73.986427,40.738529|-73....                   65
# 4  -74.006656,40.740594|-74.007473,40.740938|-74....                   65
#
#    minimum temperature  average temperature precipitation snow fall snow depth
# 0                   46                 55.5           0.0       0.0        0.0
# 1                   46                 55.5           0.0       0.0        0.0
# 2                   46                 55.5           0.0       0.0        0.0
# 3                   46                 55.5           0.0       0.0        0.0
# 4                   46                 55.5           0.0       0.0        0.0
#
# [5 rows x 29 columns]

# %%
df_copy.to_csv('../_data/train_with_osrm_and_weather_h.csv')

# %%
df_hourly.head()
# Out:
#                  Time  Temp.  Humidity  Dew Point  Wind Dir  Wind Speed  \
# 0 2015-12-31 02:00:00    7.8      0.89        6.1       NNE         5.6
# 1 2015-12-31 03:00:00    7.2      0.90        5.6  Variable         7.4
# 2 2015-12-31 04:00:00    7.2      0.90        5.6      Calm         0.0
# 3 2015-12-31 05:00:00    7.2      0.86        5.0        NW         7.4
# 4 2015-12-31 06:00:00    7.2      0.90        5.6      West         5.6
#
#    Gust Speed  Precip Events Conditions
# 0         0.0     0.8   None   Overcast
# 1         0.0     0.3   None   Overcast
# 2         0.0     0.0   None   Overcast
# 3         0.0     0.0   None   Overcast
# 4         0.0     0.0   None   Overcast

# %%
df_merged = df_copy.merge(df_hourly, how='left', on='Time')

# %%
df_hourly.iloc[2901]
# Out:
# Time          2016-04-30 23:00:00
# Temp.                        10.6
# Humidity                     0.56
# Dew Point                     2.2
# Wind Dir                      SSE
# Wind Speed                     13
# Gust Speed                      0
# Precip                          0
# Events                       None
# Conditions                  Clear
# Name: 2901, dtype: object

# %%
df_merged.head()
# Out:
#           id  vendor_id                Time     pickup_datetime  \
# 0  id3495688          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 1  id3051282          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 2  id0082851          1 2016-04-30 23:00:00 2016-04-30 23:59:00
# 3  id0515725          2 2016-04-30 23:00:00 2016-04-30 23:58:00
# 4  id1872374          2 2016-04-30 23:00:00 2016-04-30 23:58:00
#
#   dropoff_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# 0      5/1/16 0:24                1        -73.987793        40.724792
# 1      5/1/16 0:22                1        -73.957596        40.717770
# 2      5/1/16 0:17                2        -74.000954        40.742031
# 3      5/1/16 0:12                1        -73.985733        40.738258
# 4      5/1/16 0:17                1        -74.006615        40.740650
#
#    dropoff_longitude  dropoff_latitude    ...     snow depth  Temp. Humidity  \
# 0         -73.975616         40.656445    ...            0.0   10.6     0.56
# 1         -73.951424         40.775230    ...            0.0   10.6     0.56
# 2         -73.947708         40.782200    ...            0.0   10.6     0.56
# 3         -73.993179         40.754890    ...            0.0   10.6     0.56
# 4         -73.985619         40.723362    ...            0.0   10.6     0.56
#
#   Dew Point  Wind Dir  Wind Speed  Gust Speed Precip Events Conditions
# 0       2.2       SSE        13.0         0.0    0.0   None      Clear
# 1       2.2       SSE        13.0         0.0    0.0   None      Clear
# 2       2.2       SSE        13.0         0.0    0.0   None      Clear
# 3       2.2       SSE        13.0         0.0    0.0   None      Clear
# 4       2.2       SSE        13.0         0.0    0.0   None      Clear
#
# [5 rows x 38 columns]

# %% [markdown]
# ### df + osrm + weather + hourly weather 저장

# %%
df_merged.to_csv('../_data/train_with_osrm_and_weather_hourly.csv')
