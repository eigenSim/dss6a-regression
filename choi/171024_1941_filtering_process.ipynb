# %%
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk

import matplotlib as mpl
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()

# %%
# 경로 변수 (고정)


trainfile = '../_data/train_03_997.csv'
old_trainfile = '../_data/train.csv'
kaggle_trainfile = '../_data/train_k.csv'

testfile = '../_data/test_clean.csv'
old_testfile = '../_data/test.csv'

train_171016 = '../_data/171016_dow_hr_pas_L2_dur_only.csv'
train_osrm = '../_data/train_with_osrm.csv'
train_osrm_weather = '../_data/train_with_osrm_and_weather.csv'
train_osrm_weather_hourly = '../_data/train_with_osrm_and_weather_hourly.csv'
train_dropped_nan_fixed = '../_data/train__dropped__no_disaster_nan_fixed.csv'
train_added_airps = '../_data/train__dropped__lnglat_saved__airports__no_disaster.csv'
train_added_airps_cleaned = '../_data/train__dropped__cleaned__airports__no_disaster.csv'
train_added_airps_disas_cleaned = '../_data/train__dropped__cleaned__eval__airports__disaster.csv'
train_added_weekhr = '../_data/train__dropped__cleaned__eval__a_d_weekhour.csv'
train_added_manh = '../_data/train__dropped__air_bliz_weekhr_manh.csv'
train_all_vars_rough = '../_data/train__all_vars__rough.csv'

train_701778_all_vars = '../_data/train__701778__all_vars.csv'
train_700806_all_vars_cooks_dropped = '../_data/train_700806_dropped_cooks.csv'
train_700789_all_vars_cooks_dropped_circle_filter = '../_data/train_700789_dropped_cooks__circle_filter.csv'
train_700789_all_vars_cdcf_kmeans = '../_data/train_kmeans_30_added.csv'
train_700419_all_vars_cdcf150kmh_km60 = '../_data/train_kmeans_60_added_cooksd_circle_150kmh.csv'

train_700419_all_vars_4d_clust120 = '../_data/train_kmeans_4D_120.csv'
train_700419_all_vars_4d_clust120_speed = '../_data/train_kmeans_4D_120_clustspeed.csv'
train_700419_all_vars_4d_clust120_speed_glob = '../_data/train_kmeans_4D_120_clustspeed_globalized.csv'

train_700419 = '../_data/train_700419_recent.csv'
train_697355 = '../_data/train_697355_rsq_0722.csv'
train_697349 = '../_data/train_697349_rsq_0723.csv'
train_697284 = '../_data/train_697284_rsq_0725.csv'
train_696688 = '../_data/train_696688_rsq_0731.csv'

test_recent = '../_data/test_backup_clean_todo_clust.csv'

trains = [train_700419, train_697355, train_697349, train_697284, train_696688]

train_latest = trains[0]

# %%
pd.options.display.max_columns = 50

# %%
df_train = pd.read_csv(train_701778_all_vars)

# %%
df_train.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 30 columns]

# %%
df_train.shape
# Out:
# (701778, 30)

# %% [markdown]
# # circle filter (`701778 -> 701760`)

# %%
df_copy = df_train.copy()

# %%
center_coords = np.array((-74.002786, 40.728319))  # NYC Washington Square Park
edge_coords = np.array((-75.431274, 39.771776))  # approx. 100 miles away

# %%
taxi_radius = np.linalg.norm(center_coords - edge_coords)
taxi_radius
# Out:
# 1.7191720324019342

# %%
def within_radius(lng, lat):
    return np.linalg.norm(center_coords - np.array([lng, lat])) < taxi_radius

# %% [markdown]
# ## filter pickup coordinates outside of radius

# %%
df_circlep = df_train.loc[np.vectorize(within_radius)(\
                            df_train['p_lng'],
                            df_train['p_lat'])].copy()
df_circlep.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 30 columns]

# %%
df_circlep.shape
# Out:
# (701764, 30)

# %% [markdown]
# ## filter dropoff coordinates outside of radius

# %%
df_circle = df_circlep.loc[np.vectorize(within_radius)(\
                            df_circlep['d_lng'],
                            df_circlep['d_lat'])].copy()
df_circle.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 30 columns]

# %%
df_circle.shape
# Out:
# (701760, 30)

# %%
df_circle.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 30 columns]

# %% [markdown]
# ## resulting extremes

# %%
for col in ['p_lng', 'p_lat', 'd_lng', 'd_lat']:
    print(col)
    print(" min = {}".format(np.percentile(df_circle[col], 0)))
    print(" 0.3 = {}".format(np.percentile(df_circle[col], 0.3)))
    print("99.7 = {}".format(np.percentile(df_circle[col], 99.7)))
    print(" max = {}".format(np.percentile(df_circle[col], 100)))
# Out:
# p_lng
#  min = -75.24149323
#  0.3 = -74.01612854
# 99.7 = -73.7767868
#  max = -73.22267914
# p_lat
#  min = 40.22580338
#  0.3 = 40.64365005
# 99.7 = 40.82313707649
#  max = 41.69679642
# d_lng
#  min = -75.57015228
#  0.3 = -74.03293573416
# 99.7 = -73.77871152351
#  max = -72.67115021
# d_lat
#  min = 40.22579956
#  0.3 = 40.63078138351
# 99.7 = 40.86590746649
#  max = 41.69335175

# %% [markdown]
# # Fox criterion filter (`701760 -> 700789`)

# %%
df_circle.to_csv('../_data/train__701760__in_circle__all_vars.csv', index=False)

# %%
center_coords = np.array((-74.002786, 40.728319))
edge_coords = np.array((-75.431274, 39.771776))

taxi_radius = np.linalg.norm(center_coords - edge_coords)
taxi_radius

taxi_radius = 1

def within_radius(lng, lat):
    return np.linalg.norm(center_coords - np.array([lng, lat])) < taxi_radius

df_circlep = df_train.loc[np.vectorize(within_radius)(\
                            df_train['p_lng'],
                            df_train['p_lat'])].copy()
df_circlep.head()

df_circlep.shape

df_circle = df_circlep.loc[np.vectorize(within_radius)(\
                            df_circlep['d_lng'],
                            df_circlep['d_lat'])].copy()
df_circle.head()

df_circle.shape

df_circle.head()

for col in ['p_lng', 'p_lat', 'd_lng', 'd_lat']:
    print(col)
    print(" min = {}".format(np.percentile(df_circle[col], 0)))
    print(" 0.3 = {}".format(np.percentile(df_circle[col], 0.3)))
    print("99.7 = {}".format(np.percentile(df_circle[col], 99.7)))
    print(" max = {}".format(np.percentile(df_circle[col], 100)))

df_circle.to_csv('../_data/train__701760__in_circle__all_vars.csv', index=False)

# %%
df_copy = df_circle.copy()

# %%
from datetime import datetime
t0 = datetime.now()
mod = sm.OLS.from_formula('dur ~ C(is_hol)\
                               + C(dow):C(hr)\
                               + scale(total_dist) - 1', data=df_copy)
res = mod.fit()
print('done')
t1 = datetime.now()

print("{} sec".format((t1 - t0).seconds))
# Out:
# done
# 35 sec

# %%
res.df_resid
# Out:
# 701590.0

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    dur   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     28.73
# Date:                Tue, 24 Oct 2017   Prob (F-statistic):               0.00
# Time:                        19:48:11   Log-Likelihood:            -7.1833e+06
# No. Observations:              701760   AIC:                         1.437e+07
# Df Residuals:                  701590   BIC:                         1.437e+07
# Df Model:                         169
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# C
# C(dow)[T.Wednesday]:C(hr)[20]   -81.1779    118.730     -0.684      0.494    -313.885     151.529
# C(dow)[T.Monday]:C(hr)[21]     -207.9035    126.034     -1.650      0.099    -454.927      39.120
# C(dow)[T.Saturday]:C(hr)[21]     74.5548    122.750      0.607      0.544    -166.031     315.141
# C(dow)[T.Sunday]:C(hr)[21]      -57.8509    135.081     -0.428      0.668    -322.605     206.903
# C(dow)[T.Thursday]:C(hr)[21]    -40.8092    117.707     -0.347      0.729    -271.511     189.893
# C(dow)[T.Tuesday]:C(hr)[21]    -100.8094    121.319     -0.831      0.406    -338.590     136.971
# C(dow)[T.Wednesday]:C(hr)[21]  -105.8673    119.527     -0.886      0.376    -340.135     128.401
# C(dow)[T.Monday]:C(hr)[22]     -187.2954    131.398     -1.425      0.154    -444.832      70.241
# C(dow)[T.Saturday]:C(hr)[22]    918.4336    119.283      7.700      0.000     684.643    1152.224
# C(dow)[T.Sunday]:C(hr)[22]     -122.2892    138.991     -0.880      0.379    -394.708     150.130
# C(dow)[T.Thursday]:C(hr)[22]     -3.4172    118.375     -0.029      0.977    -235.428     228.593
# C(dow)[T.Tuesday]:C(hr)[22]     -44.6203    123.951     -0.360      0.719    -287.560     198.319
# C(dow)[T.Wednesday]:C(hr)[22]   -77.3861    121.631     -0.636      0.525    -315.779     161.007
# C(dow)[T.Monday]:C(hr)[23]     -394.9831    146.590     -2.694      0.007    -682.295    -107.671
# C(dow)[T.Saturday]:C(hr)[23]    -36.7521    117.297     -0.313      0.754    -266.650     193.146
# C(dow)[T.Sunday]:C(hr)[23]     -251.3074    151.468     -1.659      0.097    -548.180      45.565
# C(dow)[T.Thursday]:C(hr)[23]   -228.4762    123.101     -1.856      0.063    -469.750      12.797
# C(dow)[T.Tuesday]:C(hr)[23]    -370.2026    135.613     -2.730      0.006    -635.999    -104.406
# C(dow)[T.Wednesday]:C(hr)[23]  -229.6035    131.171     -1.750      0.080    -486.693      27.486
# scale(total_dist)               546.7316      8.123     67.304      0.000     530.810     562.653
# ===============================================================================
# Omnibus:                  3942317.665   Durbin-Watson:                    2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   608762569354130.875
# Skew:                         329.593   Prob(JB):                          0.00
# Kurtosis:                  144291.180   Cond. No.                          76.1
# ===============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_dropped = pd.DataFrame(columns=df_copy.columns)
df_dropped
# Out:
# Empty DataFrame
# Columns: [is_hol, blizz, m_d, dow, hr, wkhr, L2, pas_cnt, p_JFK, p_LGA, d_JFK, d_LGA, p_lng, p_lat, d_lng, d_lat, total_dist, total_time, day_max_temp, day_min_temp, day_rainfall, day_snowfall, day_snowdepth, hr_temp, hr_humid, hr_dewpt, hr_windspeed, hr_gustspeed, hr_precip, dur]
# Index: []
#
# [0 rows x 30 columns]

# %%
# dropping outliers by fox_criteria
# original author: 조성빈
def dropping_outliers1(fmla, data):
    model = sm.OLS.from_formula(fmla, data)
    result = model.fit()
    influence = result.get_influence()
    cooks_d2, pvals = influence.cooks_distance
    fox_cr = 4 / (result.df_resid -1)
    print("Fox criterion for Cook's distance:", fox_cr)
    idx = np.where(cooks_d2 > fox_cr)[0]
    df_dropped = data.loc[idx].copy()
    data = data.drop(data.index[idx])
    print("Function dropping_outliers:        " + str(len(idx)) + ' rows have been deleted')
    return data, df_dropped

# %%
df_copy = df_circle.copy()

# %%
df_copy.shape
# Out:
# (701760, 30)

# %%
t0 = datetime.now()
fmla = 'dur ~ C(is_hol) + C(dow):C(hr) + scale(total_dist) - 1'

df_copy2, df_dropped = dropping_outliers1(fmla, df_copy)

t1 = datetime.now()

print(t1 - t0)

df_copy2.head()
# Out:
# Fox criterion for Cook's distance: 5.70134366417e-06
# Function dropping_outliers:        971 rows have been deleted
# 0:00:38.491344
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    ...   day_rainfall  day_snowfall  day_snowdepth  hr_temp  hr_humid  \
# 0  ...            0.0           0.0            0.0     10.6      0.56
# 1  ...            0.0           0.0            0.0     10.6      0.56
# 2  ...            0.0           0.0            0.0     10.6      0.56
# 3  ...            0.0           0.0            0.0     10.6      0.56
# 4  ...            0.0           0.0            0.0     10.6      0.56
#
#    hr_dewpt  hr_windspeed  hr_gustspeed  hr_precip   dur
# 0       2.2          13.0           0.0        0.0  1454
# 1       2.2          13.0           0.0        0.0  1409
# 2       2.2          13.0           0.0        0.0  1081
# 3       2.2          13.0           0.0        0.0   800
# 4       2.2          13.0           0.0        0.0  1151
#
# [5 rows x 30 columns]

# %% [markdown]
# ## dropped rows
# * high duration

# %%
df_dropped.head()
# Out:
#       is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 55     False      0  430  Saturday  23   143  0.020996        1  False  False
# 405    False      0  430  Saturday  22   142  0.010217        2  False  False
# 991    False      0  430  Saturday  21   141  0.014269        1  False  False
# 2617   False      0  430  Saturday  16   136  0.180187        1   True  False
# 3201   False      0  430  Saturday  14   134  0.027076        5  False  False
#
#       d_JFK  d_LGA      p_lng      p_lat      d_lng      d_lat  total_dist  \
# 55    False  False -74.005669  40.745209 -73.989098  40.758102      2512.4
# 405   False  False -73.976662  40.747765 -73.967712  40.752693      1265.4
# 991   False  False -73.991150  40.750629 -73.987946  40.736725      1889.9
# 2617  False  False -73.782318  40.644741 -73.944893  40.722439     20929.1
# 3201  False  False -73.990387  40.737202 -74.012169  40.721119      3387.8
#
#       total_time  day_max_temp  day_min_temp  day_rainfall  day_snowfall  \
# 55         309.9            65            46           0.0           0.0
# 405        135.2            65            46           0.0           0.0
# 991        265.7            65            46           0.0           0.0
# 2617      1333.6            65            46           0.0           0.0
# 3201       420.1            65            46           0.0           0.0
#
#       day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  hr_gustspeed  \
# 55              0.0     10.6      0.56       2.2          13.0           0.0
# 405             0.0     11.1      0.53       1.7           5.6           0.0
# 991             0.0     11.7      0.47       0.6          11.1           0.0
# 2617            0.0     16.7      0.34       0.6          11.1           0.0
# 3201            0.0     16.7      0.38       2.2          13.0           0.0
#
#       hr_precip    dur
# 55          0.0  86073
# 405         0.0  86323
# 991         0.0  86356
# 2617        0.0  26722
# 3201        0.0  86317

# %%
top_5 = df_copy2['dur'].sort_values(ascending=False).head().index

# %% [markdown]
# ## remaining rows
# * not ideal

# %%
df_copy2.loc[top_5]
# Out:
#         is_hol  blizz  m_d      dow  hr  wkhr        L2  pas_cnt  p_JFK  \
# 342274   False      0  304   Friday  18   114  0.033882        1  False
# 234110   False      0  322  Tuesday  19    43  0.126448        1  False
# 609652   False      0  117   Sunday  17   161  0.012918        1  False
# 78734    False      0  417   Sunday  11   155  0.010871        1   True
# 533186   False      0  201   Monday  18    18  0.046676        1  False
#
#         p_LGA  d_JFK  d_LGA      p_lng      p_lat      d_lng      d_lat  \
# 342274  False  False  False -73.981911  40.778702 -73.957123  40.801800
# 234110   True  False  False -73.870949  40.773830 -73.994087  40.745090
# 609652  False  False  False -73.982101  40.755665 -73.991684  40.764328
# 78734   False  False  False -73.790039  40.646923 -73.793320  40.657288
# 533186  False  False  False -73.972336  40.761059 -73.998100  40.722137
#
#         total_dist  total_time  day_max_temp  day_min_temp  day_rainfall  \
# 342274      4892.3       339.9            39            30          0.11
# 234110     14809.7      1017.7            56            35          0.00
# 609652      2370.8       226.5            42            30          0.05
# 78734       2416.6       266.7            75            44          0.00
# 533186      5602.9       687.3            59            44          0.01
#
#         day_snowfall  day_snowdepth  hr_temp  hr_humid  hr_dewpt  \
# 342274           0.4            0.0      3.9      0.45      -7.2
# 234110           0.0            0.0     12.8      0.29      -5.0
# 609652           0.4            0.0     -0.6      0.76      -4.4
# 78734            0.0            0.0     13.3      0.37      -1.1
# 533186           0.0            2.0     11.1      0.47       0.0
#
#         hr_windspeed  hr_gustspeed  hr_precip    dur
# 342274          18.5          31.5        0.0  18439
# 234110          13.0           0.0        0.0  15418
# 609652          11.1           0.0        0.0  14243
# 78734            0.0           0.0        0.0  14160
# 533186           5.6           0.0        0.3  13850

# %%
df_dropped['dur'].sort_values(ascending=False).head()
# Out:
# 991      86356
# 405      86323
# 3201     86317
# 15689    86299
# 13157    86245
# Name: dur, dtype: int64

# %%
df_copy2.shape
# Out:
# (700789, 30)

# %%
df_copy2.to_csv('../_data/train_700806_dropped_cooks.csv', index=False)

# %%
df_copy = df_copy2.copy()

# %%
t0 = datetime.now()
modelz = sm.OLS.from_formula(fmla, df_copy2)
resz = modelz.fit()
print('done')
t1 = datetime.now()
print(t1-t0)
# Out:
# done
# 0:00:32.735062

# %% [markdown]
# # average speed filter (150km/h) `700789 -> 700419`

# %%
df_copy.insert(17, 'avg_spd', 3.6*df_copy['total_dist'] / df_copy['dur'])
df_copy.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    d_JFK  d_LGA      p_lng      p_lat      d_lng      d_lat  total_dist  \
# 0  False  False -73.987793  40.724792 -73.975616  40.656445     10010.9
# 1  False  False -73.957596  40.717770 -73.951424  40.775230     10357.0
# 2  False  False -74.000954  40.742031 -73.947708  40.782200      9275.8
# 3  False  False -73.985733  40.738258 -73.993179  40.754890      2726.9
# 4  False  False -74.006615  40.740650 -73.985619  40.723362      3455.8
#
#      avg_spd  total_time  day_max_temp  day_min_temp  day_rainfall  \
# 0  24.786272       861.2            65            46           0.0
# 1  26.462172       786.3            65            46           0.0
# 2  30.890731       703.9            65            46           0.0
# 3  12.271050       298.0            65            46           0.0
# 4  10.808758       458.2            65            46           0.0
#
#    day_snowfall  day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  \
# 0           0.0            0.0     10.6      0.56       2.2          13.0
# 1           0.0            0.0     10.6      0.56       2.2          13.0
# 2           0.0            0.0     10.6      0.56       2.2          13.0
# 3           0.0            0.0     10.6      0.56       2.2          13.0
# 4           0.0            0.0     10.6      0.56       2.2          13.0
#
#    hr_gustspeed  hr_precip   dur
# 0           0.0        0.0  1454
# 1           0.0        0.0  1409
# 2           0.0        0.0  1081
# 3           0.0        0.0   800
# 4           0.0        0.0  1151

# %%
df_copy.loc[df_copy['avg_spd'] > 150, 'avg_spd'].shape
# Out:
# (370,)

# %%
df_copy.loc[df_copy['avg_spd'] > 150, 'avg_spd'].index
# Out:
# Int64Index([  2820,   9603,  12063,  12486,  15405,  16299,  19217,  21857,
#              22591,  23861,
#             ...
#             682556, 684886, 686714, 693314, 693708, 694426, 694563, 695946,
#             701288, 701544],
#            dtype='int64', length=370)

# %%
df_bkup = df_copy.copy()

# %%
df_copy.drop(df_copy.loc[df_copy['avg_spd'] > 150, 'avg_spd'].index, inplace=True)

# %%
df_copy.head()
# Out:
#    is_hol  blizz  m_d       dow  hr  wkhr        L2  pas_cnt  p_JFK  p_LGA  \
# 0   False      0  430  Saturday  23   143  0.069424        1  False  False
# 1   False      0  430  Saturday  23   143  0.057791        1  False  False
# 2   False      0  430  Saturday  23   143  0.066698        2  False  False
# 3   False      0  430  Saturday  23   143  0.018223        1  False  False
# 4   False      0  430  Saturday  23   143  0.027198        1  False  False
#
#    d_JFK  d_LGA      p_lng      p_lat      d_lng      d_lat  total_dist  \
# 0  False  False -73.987793  40.724792 -73.975616  40.656445     10010.9
# 1  False  False -73.957596  40.717770 -73.951424  40.775230     10357.0
# 2  False  False -74.000954  40.742031 -73.947708  40.782200      9275.8
# 3  False  False -73.985733  40.738258 -73.993179  40.754890      2726.9
# 4  False  False -74.006615  40.740650 -73.985619  40.723362      3455.8
#
#      avg_spd  total_time  day_max_temp  day_min_temp  day_rainfall  \
# 0  24.786272       861.2            65            46           0.0
# 1  26.462172       786.3            65            46           0.0
# 2  30.890731       703.9            65            46           0.0
# 3  12.271050       298.0            65            46           0.0
# 4  10.808758       458.2            65            46           0.0
#
#    day_snowfall  day_snowdepth  hr_temp  hr_humid  hr_dewpt  hr_windspeed  \
# 0           0.0            0.0     10.6      0.56       2.2          13.0
# 1           0.0            0.0     10.6      0.56       2.2          13.0
# 2           0.0            0.0     10.6      0.56       2.2          13.0
# 3           0.0            0.0     10.6      0.56       2.2          13.0
# 4           0.0            0.0     10.6      0.56       2.2          13.0
#
#    hr_gustspeed  hr_precip   dur
# 0           0.0        0.0  1454
# 1           0.0        0.0  1409
# 2           0.0        0.0  1081
# 3           0.0        0.0   800
# 4           0.0        0.0  1151

# %%
df_copy.shape
# Out:
# (700419, 31)
