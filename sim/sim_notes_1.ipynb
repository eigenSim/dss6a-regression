# %%
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk

import matplotlib as mpl
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()

import os
from os.path import dirname

# %% [markdown]
# sysname = os.sys.platform
# if sysname == 'win32':
#     _sl = '\\'
# elif sysname == 'linux':
#     _sl = '/'
#
# file_to_get = 'train.csv'
#
# taxi_df = pd.read_csv(os.getcwd() + '{}_data{}'.format(_sl, _sl)\
#                       + file_to_get)
# taxi_df.head()

# %%
taxi_df = pd.read_csv(os.getcwd()+'/'+'train.csv')
taxi_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e4ee715d4daf> in <module>()
# ----> 1 taxi_df = pd.read_csv(os.getcwd()+'/'+'train.csv')
#       2 taxi_df.head()
#
# ...

# %%
taxi_df
# Out:
#                id  vendor_id pickup_datetime dropoff_datetime  \
# 0       id3495688          1   4/30/16 23:59      5/1/16 0:24
# 1       id3051282          1   4/30/16 23:59      5/1/16 0:22
# 2       id0082851          1   4/30/16 23:59      5/1/16 0:17
# 3       id0515725          2   4/30/16 23:58      5/1/16 0:12
# 4       id1872374          2   4/30/16 23:58      5/1/16 0:17
# 5       id0312189          1   4/30/16 23:58      5/1/16 0:25
# 6       id1462929          1   4/30/16 23:58      5/1/16 0:34
# 7       id3799362          1   4/30/16 23:58      5/1/16 0:39
# 8       id3607754          2   4/30/16 23:58      5/1/16 0:24
# 9       id1733007          2   4/30/16 23:58      5/1/16 0:37
# 10      id2384995          2   4/30/16 23:58      5/1/16 0:01
# 11      id1368707          1   4/30/16 23:58      5/1/16 0:07
# 12      id1885646          1   4/30/16 23:57      5/1/16 0:01
# 13      id0475908          1   4/30/16 23:57      5/1/16 0:09
# ...

# %%
# %matplotlib inline

# %%
data =  pd.read_csv(os.getcwd()+'/'+'train.csv', parse_dates = ['pickup_datetime', 'trip_duration'])
data
# Out:
#                id  vendor_id     pickup_datetime dropoff_datetime  \
# 0       id3495688          1 2016-04-30 23:59:00      5/1/16 0:24
# 1       id3051282          1 2016-04-30 23:59:00      5/1/16 0:22
# 2       id0082851          1 2016-04-30 23:59:00      5/1/16 0:17
# 3       id0515725          2 2016-04-30 23:58:00      5/1/16 0:12
# 4       id1872374          2 2016-04-30 23:58:00      5/1/16 0:17
# 5       id0312189          1 2016-04-30 23:58:00      5/1/16 0:25
# 6       id1462929          1 2016-04-30 23:58:00      5/1/16 0:34
# 7       id3799362          1 2016-04-30 23:58:00      5/1/16 0:39
# 8       id3607754          2 2016-04-30 23:58:00      5/1/16 0:24
# 9       id1733007          2 2016-04-30 23:58:00      5/1/16 0:37
# 10      id2384995          2 2016-04-30 23:58:00      5/1/16 0:01
# 11      id1368707          1 2016-04-30 23:58:00      5/1/16 0:07
# 12      id1885646          1 2016-04-30 23:57:00      5/1/16 0:01
# ...

# %%
p_lng = data.pickup_longitude
p_lat = data.pickup_latitude
d_lng = data.dropoff_longitude
d_lat = data.dropoff_latitude

# %%
def lat_lng_to_pixels(lat, lng):
    lat_rad = lat * np.pi / 180.0
    lat_rad = np.log(np.tan((lat_rad + np.pi / 2.0) / 2.0))
    x = 100 * (lng + 180.0) / 360.0
    y = 100 * (lat_rad - np.pi) / (2.0 * np.pi)
    return (x, y)

# %%
px, py = lat_lng_to_pixels(p_lat, p_lng)

# %%
px
# Out:
# 0         29.447835
# 1         29.456223
# 2         29.444180
# 3         29.448407
# 4         29.442607
# 5         29.445207
# 6         29.445962
# 7         29.479707
# 8         29.449902
# 9         29.504876
# 10        29.445163
# 11        29.446827
# 12        29.445612
# 13        29.444497
# 14        29.450798
# 15        29.456978
# 16        29.447047
# 17        29.449984
# 18        29.442637
# 19        29.450453
# 20        29.449484
# 21        29.445907
# 22        29.444930
# 23        29.452322
# 24        29.458209
# 25        29.447560
# 26        29.457764
# 27        29.445320
# 28        29.455416
# 29        29.444305
#             ...
# 701748    29.449331
# 701749    29.447844
# 701750    29.452258
# 701751    29.479711
# 701752    29.446615
# 701753    29.457321
# 701754    29.449372
# 701755    29.447691
# 701756    29.452161
# 701757    29.448259
# 701758    29.450410
# 701759    29.445845
# 701760    29.462278
# 701761    29.447094
# ...

# %%
plt.scatter(px, py)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize = (8, 6))
plt.scatter(px, py, s = 1, alpha = 0.03)
plt.axis('equal')
plt.xlim(29.40, 29.55)
plt.ylim(-37.63, -37.54)
plt.axis('off')
#맨하튼 지역과 유사한 지도가 표시됨
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-209a87a32186> in <module>()
#       1 plt.figure(figsize = (8, 6))
# ----> 2 plt.scatter(px, py, s = 1, alpha = 0.03)
#       3 plt.axis('equal')
#       4 plt.xlim(29.40, 29.55)
#       5 plt.ylim(-37.63, -37.54)
#
# NameError: name 'px' is not defined

# %%
data.trip_duration.hist(bins = np.linspace(0., 10., 100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-1f004d1a7c3f> in <module>()
# ----> 1 data.trip_duration.hist(bins = np.linspace(0., 10., 100))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2198         values = self.dropna().values
#    2199
# -> 2200         ax.hist(values, bins=bins, **kwds)
#    2201         ax.grid(grid)
#    2202         axes = np.array([ax])
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
# ...
